# %%
import nltk 
from nltk.tokenize import word_tokenize

# %%
# reading corpus 
# note you can use any corpuses of your choice

#writing all gutenberg corpus in one file
with open("result.txt", "w") as f:
    for filename in nltk.corpus.gutenberg.fileids():
        f.write(nltk.corpus.gutenberg.raw(filename))
        
        
# reading data file
with open("result.txt", "r") as f:
    data = f.read()

# %%
data[0:50]
# Out:
# '[Emma by Jane Austen 1816]\n\nVOLUME I\n\nCHAPTER I\n\n\n'

# %%
#approximate number of words
len(data.split())
# Out:
# 2135242

# %%
#extract sents

# Split by newline character
sentences = data.split('\n')

# Remove leading and trailing spaces
sentences = [s.strip() for s in sentences]

# Drop Empty Sentences
sentences = [s for s in sentences if len(s) > 0]

sentences[0:5]
# Out:
# ['[Emma by Jane Austen 1816]',
#  'VOLUME I',
#  'CHAPTER I',
#  'Emma Woodhouse, handsome, clever, and rich, with a comfortable home',
#  'and happy disposition, seemed to unite some of the best blessings']

# %%
# tokenized sentences
tokenized = []

# Iterate through sentences
for sentence in sentences:

    # Convert to lowercase
    sentence = sentence.lower()

    # Convert to a list of words
    token = word_tokenize(sentence)

    # Append to list
    tokenized.append(token)
    
    
tokenized[0:3]
# Out:
# [['[', 'emma', 'by', 'jane', 'austen', '1816', ']'],
#  ['volume', 'i'],
#  ['chapter', 'i']]

# %%
# building tri_dictionary dictionary
# tri_dic contains the frequency for every three words in each sentence

tri_dic = {}

for token_sent in tokenized:
    
    m = len(token_sent) -2
    
    for i in range(m):

        tri = token_sent[i:i+3]
        
        tri = f'{tri[0]}_{tri[1]}_{tri[2]}'
        
        if tri in tri_dic.keys():
            tri_dic[tri] += 1

        else:
            tri_dic[tri] = 1

# %%
tri_dic
# Out:
# {'[_emma_by': 1,
#  'emma_by_jane': 1,
#  'by_jane_austen': 3,
#  'jane_austen_1816': 1,
#  'austen_1816_]': 1,
#  'emma_woodhouse_,': 4,
#  'woodhouse_,_handsome': 1,
#  ',_handsome_,': 5,
#  'handsome_,_clever': 1,
#  ',_clever_,': 1,
#  'clever_,_and': 3,
#  ',_and_rich': 4,
#  'and_rich_,': 1,
#  'rich_,_with': 1,
#  ',_with_a': 376,
#  'with_a_comfortable': 1,
#  'a_comfortable_home': 2,
#  'and_happy_disposition': 1,
#  'happy_disposition_,': 1,
#  'disposition_,_seemed': 1,
#  ',_seemed_to': 18,
#  'seemed_to_unite': 1,
#  'to_unite_some': 1,
#  'unite_some_of': 1,
#  'some_of_the': 106,
#  'of_the_best': 23,
#  'the_best_blessings': 2,
#  'of_existence_;': 2,
#  'existence_;_and': 1,
#  ';_and_had': 17,
#  'and_had_lived': 3,
#  'had_lived_nearly': 1,
#  'lived_nearly_twenty-one': 1,
#  'nearly_twenty-one_years': 1,
#  'twenty-one_years_in': 1,
#  'years_in_the': 10,
#  'in_the_world': 233,
#  'with_very_little': 4,
#  'very_little_to': 5,
#  'little_to_distress': 2,
#  'to_distress_or': 1,
#  'distress_or_vex': 1,
#  'or_vex_her': 1,
#  'vex_her_.': 2,
#  'she_was_the': 12,
#  'was_the_youngest': 5,
#  'the_youngest_of': 5,
#  'youngest_of_the': 3,
#  'of_the_two': 64,
#  'the_two_daughters': 2,
#  'two_daughters_of': 2,
#  'daughters_of_a': 2,
#  'of_a_most': 6,
#  'a_most_affectionate': 2,
#  'most_affectionate_,': 1,
#  'indulgent_father_;': 1,
#  'father_;_and': 27,
#  'and_had_,': 5,
#  'had_,_in': 11,
#  ',_in_consequence': 6,
#  'in_consequence_of': 9,
#  'consequence_of_her': 1,
#  'of_her_sister': 25,
#  "her_sister_'s": 40,
#  "sister_'s_marriage": 2,
#  "'s_marriage_,": 5,
#  'been_mistress_of': 3,
#  'mistress_of_his': 1,
#  'of_his_house': 29,
#  'his_house_from': 1,
#  'house_from_a': 1,
#  'from_a_very': 3,
#  'a_very_early': 5,
#  'very_early_period': 2,
#  'early_period_.': 1,
#  'period_._her': 1,
#  '._her_mother': 6,
#  'had_died_too': 1,
#  'died_too_long': 1,
#  'too_long_ago': 1,
#  'long_ago_for': 1,
#  'ago_for_her': 1,
#  'for_her_to': 29,
#  'her_to_have': 5,
#  'to_have_more': 4,
#  'have_more_than': 10,
#  'more_than_an': 5,
#  'than_an_indistinct': 1,
#  'remembrance_of_her': 2,
#  'of_her_caresses': 1,
#  'her_caresses_;': 1,
#  'caresses_;_and': 1,
#  ';_and_her': 30,
#  'and_her_place': 1,
#  'her_place_had': 1,
#  'place_had_been': 1,
#  'had_been_supplied': 2,
#  'by_an_excellent': 1,
#  'an_excellent_woman': 2,
#  'excellent_woman_as': 1,
#  'woman_as_governess': 1,
#  'as_governess_,': 2,
#  'governess_,_who': 1,
#  ',_who_had': 191,
#  'who_had_fallen': 1,
#  'had_fallen_little': 1,
#  'fallen_little_short': 1,
#  'of_a_mother': 2,
#  'a_mother_in': 3,
#  'mother_in_affection': 1,
#  'in_affection_.': 1,
#  'sixteen_years_had': 1,
#  'years_had_miss': 1,
#  'had_miss_taylor': 2,
#  'miss_taylor_been': 1,
#  'taylor_been_in': 1,
#  'been_in_mr.': 1,
#  'in_mr._woodhouse': 2,
#  "mr._woodhouse_'s": 25,
#  "woodhouse_'s_family": 2,
#  "'s_family_,": 8,
#  'less_as_a': 1,
#  'as_a_governess': 1,
#  'a_governess_than': 1,
#  'governess_than_a': 1,
#  'than_a_friend': 1,
#  'a_friend_,': 27,
#  'friend_,_very': 1,
#  ',_very_fond': 1,
#  'very_fond_of': 22,
#  'fond_of_both': 1,
#  'of_both_daughters': 1,
#  'both_daughters_,': 1,
#  'but_particularly_of': 1,
#  'particularly_of_emma': 1,
#  'of_emma_.': 2,
#  'emma_._between': 1,
#  '._between__them_': 1,
#  'between__them__it': 1,
#  '_them__it_was': 1,
#  'it_was_more': 11,
#  'was_more_the': 1,
#  'more_the_intimacy': 1,
#  'of_sisters_.': 1,
#  'sisters_._even': 1,
#  '._even_before': 1,
#  'even_before_miss': 1,
#  'before_miss_taylor': 1,
#  'miss_taylor_had': 4,
#  'taylor_had_ceased': 1,
#  'had_ceased_to': 7,
#  'ceased_to_hold': 1,
#  'to_hold_the': 8,
#  'hold_the_nominal': 1,
#  'office_of_governess': 1,
#  'of_governess_,': 1,
#  'governess_,_the': 1,
#  ',_the_mildness': 1,
#  'the_mildness_of': 2,
#  'mildness_of_her': 1,
#  'of_her_temper': 4,
#  'her_temper_had': 1,
#  'temper_had_hardly': 1,
#  'had_hardly_allowed': 1,
#  'her_to_impose': 1,
#  'to_impose_any': 1,
#  'impose_any_restraint': 1,
#  'any_restraint_;': 1,
#  'restraint_;_and': 1,
#  ';_and_the': 642,
#  'and_the_shadow': 5,
#  'the_shadow_of': 51,
#  'shadow_of_authority': 1,
#  'of_authority_being': 1,
#  'now_long_passed': 1,
#  'long_passed_away': 2,
#  'passed_away_,': 9,
#  'away_,_they': 9,
#  ',_they_had': 31,
#  'they_had_been': 47,
#  'had_been_living': 2,
#  'been_living_together': 1,
#  'living_together_as': 1,
#  'together_as_friend': 1,
#  'as_friend_and': 1,
#  'friend_very_mutually': 1,
#  'very_mutually_attached': 1,
#  'mutually_attached_,': 1,
#  'attached_,_and': 1,
#  ',_and_emma': 16,
#  'and_emma_doing': 1,
#  'emma_doing_just': 1,
#  'doing_just_what': 1,
#  'just_what_she': 3,
#  'what_she_liked': 2,
#  'she_liked_;': 1,
#  'highly_esteeming_miss': 1,
#  'esteeming_miss_taylor': 1,
#  "miss_taylor_'s": 7,
#  "taylor_'s_judgment": 1,
#  "'s_judgment_,": 2,
#  'judgment_,_but': 3,
#  ',_but_directed': 1,
#  'but_directed_chiefly': 1,
#  'directed_chiefly_by': 1,
#  'her_own_.': 20,
#  'the_real_evils': 1,
#  'real_evils_,': 1,
#  'evils_,_indeed': 1,
#  ',_indeed_,': 190,
#  'indeed_,_of': 2,
#  ',_of_emma': 2,
#  "of_emma_'s": 7,
#  "emma_'s_situation": 1,
#  "'s_situation_were": 1,
#  'situation_were_the': 1,
#  'were_the_power': 1,
#  'the_power_of': 76,
#  'power_of_having': 1,
#  'rather_too_much': 9,
#  'too_much_her': 1,
#  'much_her_own': 1,
#  'her_own_way': 8,
#  'own_way_,': 11,
#  'way_,_and': 86,
#  ',_and_a': 499,
#  'and_a_disposition': 3,
#  'a_disposition_to': 4,
#  'disposition_to_think': 1,
#  'to_think_a': 2,
#  'think_a_little': 1,
#  'too_well_of': 1,
#  'well_of_herself': 1,
#  'of_herself_;': 4,
#  'herself_;_these': 1,
#  ';_these_were': 7,
#  'these_were_the': 42,
#  'were_the_disadvantages': 1,
#  'the_disadvantages_which': 1,
#  'disadvantages_which_threatened': 1,
#  'alloy_to_her': 1,
#  'to_her_many': 1,
#  'her_many_enjoyments': 1,
#  'many_enjoyments_.': 1,
#  'enjoyments_._the': 1,
#  '._the_danger': 3,
#  'the_danger_,': 2,
#  'danger_,_however': 1,
#  ',_however_,': 351,
#  'however_,_was': 25,
#  ',_was_at': 9,
#  'was_at_present': 4,
#  'so_unperceived_,': 1,
#  'unperceived_,_that': 1,
#  ',_that_they': 339,
#  'that_they_did': 8,
#  'they_did_not': 38,
#  'did_not_by': 2,
#  'not_by_any': 11,
#  'by_any_means': 21,
#  'any_means_rank': 1,
#  'means_rank_as': 1,
#  'rank_as_misfortunes': 1,
#  'with_her_.': 36,
#  'sorrow_came_--': 1,
#  'came_--_a': 1,
#  '--_a_gentle': 1,
#  'a_gentle_sorrow': 1,
#  'gentle_sorrow_--': 1,
#  'sorrow_--_but': 1,
#  '--_but_not': 9,
#  'but_not_at': 8,
#  'not_at_all': 91,
#  'at_all_in': 16,
#  'all_in_the': 21,
#  'in_the_shape': 7,
#  'the_shape_of': 35,
#  'shape_of_any': 2,
#  'disagreeable_consciousness._--': 1,
#  'consciousness._--_miss': 1,
#  '--_miss_taylor': 1,
#  'miss_taylor_married': 1,
#  'taylor_married_.': 1,
#  'married_._it': 1,
#  '._it_was': 390,
#  'it_was_miss': 1,
#  "taylor_'s_loss": 1,
#  "'s_loss_which": 1,
#  'loss_which_first': 1,
#  'which_first_brought': 1,
#  'first_brought_grief': 1,
#  'brought_grief_.': 1,
#  'grief_._it': 2,
#  'it_was_on': 9,
#  'was_on_the': 40,
#  'on_the_wedding-day': 1,
#  'of_this_beloved': 1,
#  'this_beloved_friend': 1,
#  'beloved_friend_that': 1,
#  'friend_that_emma': 1,
#  'that_emma_first': 1,
#  'emma_first_sat': 1,
#  'first_sat_in': 1,
#  'sat_in_mournful': 1,
#  'in_mournful_thought': 1,
#  'of_any_continuance': 1,
#  'any_continuance_.': 1,
#  'continuance_._the': 1,
#  '._the_wedding': 1,
#  'the_wedding_over': 1,
#  'wedding_over_,': 1,
#  'over_,_and': 36,
#  ',_and_the': 3175,
#  'and_the_bride-people': 1,
#  'the_bride-people_gone': 1,
#  'bride-people_gone_,': 1,
#  'her_father_and': 30,
#  'father_and_herself': 2,
#  'and_herself_were': 1,
#  'herself_were_left': 1,
#  'were_left_to': 3,
#  'left_to_dine': 2,
#  'to_dine_together': 1,
#  'dine_together_,': 1,
#  'together_,_with': 1,
#  ',_with_no': 11,
#  'with_no_prospect': 1,
#  'of_a_third': 3,
#  'a_third_to': 1,
#  'third_to_cheer': 1,
#  'to_cheer_a': 1,
#  'cheer_a_long': 1,
#  'a_long_evening': 2,
#  'long_evening_.': 1,
#  'evening_._her': 1,
#  '._her_father': 11,
#  'her_father_composed': 1,
#  'father_composed_himself': 1,
#  'to_sleep_after': 1,
#  'sleep_after_dinner': 1,
#  'after_dinner_,': 13,
#  'dinner_,_as': 3,
#  ',_as_usual': 17,
#  'as_usual_,': 25,
#  'usual_,_and': 6,
#  ',_and_she': 279,
#  'and_she_had': 46,
#  'she_had_then': 3,
#  'had_then_only': 1,
#  'then_only_to': 1,
#  'only_to_sit': 1,
#  'and_think_of': 1,
#  'think_of_what': 3,
#  'of_what_she': 15,
#  'what_she_had': 40,
#  'she_had_lost': 4,
#  'had_lost_.': 2,
#  'the_event_had': 1,
#  'event_had_every': 1,
#  'had_every_promise': 1,
#  'every_promise_of': 1,
#  'promise_of_happiness': 1,
#  'of_happiness_for': 1,
#  'happiness_for_her': 1,
#  'for_her_friend': 6,
#  'her_friend_.': 8,
#  'friend_._mr.': 1,
#  '._mr._weston': 19,
#  'was_a_man': 41,
#  'a_man_of': 125,
#  'man_of_unexceptionable': 1,
#  'of_unexceptionable_character': 1,
#  'unexceptionable_character_,': 1,
#  'character_,_easy': 1,
#  ',_easy_fortune': 1,
#  'easy_fortune_,': 1,
#  'fortune_,_suitable': 1,
#  ',_suitable_age': 1,
#  'suitable_age_,': 1,
#  'and_pleasant_manners': 1,
#  'pleasant_manners_;': 1,
#  'manners_;_and': 2,
#  ';_and_there': 123,
#  'and_there_was': 166,
#  'there_was_some': 9,
#  'was_some_satisfaction': 1,
#  'some_satisfaction_in': 2,
#  'satisfaction_in_considering': 1,
#  'with_what_self-denying': 1,
#  'what_self-denying_,': 1,
#  'self-denying_,_generous': 1,
#  ',_generous_friendship': 1,
#  'generous_friendship_she': 1,
#  'friendship_she_had': 1,
#  'she_had_always': 10,
#  'had_always_wished': 1,
#  'and_promoted_the': 1,
#  'promoted_the_match': 1,
#  'the_match_;': 2,
#  'match_;_but': 2,
#  ';_but_it': 106,
#  'but_it_was': 123,
#  'it_was_a': 258,
#  'was_a_black': 3,
#  'a_black_morning': 1,
#  "black_morning_'s": 1,
#  "morning_'s_work": 6,
#  "'s_work_for": 3,
#  'work_for_her': 1,
#  'for_her_.': 47,
#  'the_want_of': 12,
#  'want_of_miss': 1,
#  'of_miss_taylor': 3,
#  'miss_taylor_would': 1,
#  'taylor_would_be': 1,
#  'would_be_felt': 1,
#  'be_felt_every': 1,
#  'felt_every_hour': 1,
#  'every_hour_of': 7,
#  'hour_of_every': 2,
#  'of_every_day': 6,
#  'every_day_.': 20,
#  'she_recalled_her': 1,
#  'recalled_her_past': 1,
#  'her_past_kindness': 1,
#  'past_kindness_--': 1,
#  'kindness_--_the': 1,
#  '--_the_kindness': 2,
#  'the_kindness_,': 2,
#  'kindness_,_the': 2,
#  ',_the_affection': 1,
#  'the_affection_of': 6,
#  'affection_of_sixteen': 1,
#  'years_--_how': 1,
#  '--_how_she': 4,
#  'how_she_had': 5,
#  'she_had_taught': 1,
#  'had_taught_and': 1,
#  'taught_and_how': 1,
#  'and_how_she': 8,
#  'she_had_played': 2,
#  'had_played_with': 2,
#  'played_with_her': 1,
#  'with_her_from': 2,
#  'her_from_five': 1,
#  'years_old_--': 1,
#  'old_--_how': 1,
#  'she_had_devoted': 1,
#  'had_devoted_all': 1,
#  'devoted_all_her': 1,
#  'all_her_powers': 2,
#  'her_powers_to': 1,
#  'powers_to_attach': 1,
#  'to_attach_and': 1,
#  'attach_and_amuse': 1,
#  'her_in_health': 1,
#  'in_health_--': 1,
#  'health_--_and': 1,
#  '--_and_how': 10,
#  'and_how_nursed': 1,
#  'how_nursed_her': 1,
#  'nursed_her_through': 1,
#  'her_through_the': 6,
#  'through_the_various': 1,
#  'the_various_illnesses': 1,
#  'of_childhood_.': 1,
#  'childhood_._a': 1,
#  '._a_large': 4,
#  'a_large_debt': 1,
#  'large_debt_of': 1,
#  'debt_of_gratitude': 1,
#  'of_gratitude_was': 1,
#  'gratitude_was_owing': 1,
#  'was_owing_here': 1,
#  'owing_here_;': 1,
#  'here_;_but': 3,
#  ';_but_the': 171,
#  'intercourse_of_the': 2,
#  'of_the_last': 19,
#  'the_last_seven': 1,
#  'last_seven_years': 1,
#  'seven_years_,': 5,
#  'years_,_the': 7,
#  ',_the_equal': 1,
#  'the_equal_footing': 1,
#  'equal_footing_and': 1,
#  'footing_and_perfect': 1,
#  'unreserve_which_had': 1,
#  'which_had_soon': 1,
#  'had_soon_followed': 1,
#  'soon_followed_isabella': 1,
#  "followed_isabella_'s": 1,
#  "isabella_'s_marriage": 1,
#  'marriage_,_on': 1,
#  ',_on_their': 4,
#  'being_left_to': 1,
#  'left_to_each': 1,
#  'to_each_other': 33,
#  'each_other_,': 57,
#  'other_,_was': 3,
#  ',_was_yet': 3,
#  'was_yet_a': 6,
#  'yet_a_dearer': 1,
#  'a_dearer_,': 1,
#  'dearer_,_tenderer': 1,
#  ',_tenderer_recollection': 1,
#  'tenderer_recollection_.': 1,
#  'she_had_been': 110,
#  'had_been_a': 58,
#  'been_a_friend': 2,
#  'a_friend_and': 5,
#  'friend_and_companion': 1,
#  'and_companion_such': 1,
#  'companion_such_as': 1,
#  'such_as_few': 1,
#  'as_few_possessed': 1,
#  'few_possessed_:': 1,
#  'possessed_:_intelligent': 1,
#  ':_intelligent_,': 1,
#  'well-informed_,_useful': 1,
#  ',_useful_,': 2,
#  'useful_,_gentle': 1,
#  ',_gentle_,': 2,
#  'gentle_,_knowing': 1,
#  ',_knowing_all': 2,
#  'knowing_all_the': 1,
#  'all_the_ways': 5,
#  'the_ways_of': 34,
#  'ways_of_the': 13,
#  'of_the_family': 39,
#  'the_family_,': 19,
#  'interested_in_all': 2,
#  'in_all_its': 8,
#  'all_its_concerns': 2,
#  'its_concerns_,': 2,
#  'concerns_,_and': 2,
#  ',_and_peculiarly': 1,
#  'and_peculiarly_interested': 1,
#  'peculiarly_interested_in': 1,
#  'interested_in_herself': 1,
#  'in_herself_,': 4,
#  'in_every_pleasure': 1,
#  'every_pleasure_,': 1,
#  'pleasure_,_every': 1,
#  ',_every_scheme': 1,
#  'every_scheme_of': 1,
#  'scheme_of_hers': 1,
#  'of_hers_--': 1,
#  'hers_--_one': 1,
#  '--_one_to': 2,
#  'one_to_whom': 4,
#  'to_whom_she': 15,
#  'whom_she_could': 4,
#  'she_could_speak': 3,
#  'every_thought_as': 1,
#  'thought_as_it': 1,
#  'as_it_arose': 1,
#  'it_arose_,': 1,
#  'arose_,_and': 74,
#  ',_and_who': 79,
#  'and_who_had': 12,
#  'who_had_such': 3,
#  'had_such_an': 8,
#  'such_an_affection': 2,
#  'an_affection_for': 2,
#  'affection_for_her': 5,
#  'as_could_never': 1,
#  'could_never_find': 1,
#  'never_find_fault': 1,
#  'find_fault_.': 1,
#  'how_was_she': 1,
#  'was_she_to': 3,
#  'she_to_bear': 1,
#  'to_bear_the': 10,
#  'bear_the_change': 2,
#  'the_change_?': 1,
#  'change_?_--': 1,
#  '?_--_it': 9,
#  '--_it_was': 49,
#  'it_was_true': 10,
#  'was_true_that': 4,
#  'true_that_her': 1,
#  'that_her_friend': 5,
#  'her_friend_was': 4,
#  'going_only_half': 1,
#  'only_half_a': 6,
#  'half_a_mile': 12,
#  'a_mile_from': 8,
#  'mile_from_them': 2,
#  'from_them_;': 4,
#  'them_;_but': 28,
#  ';_but_emma': 6,
#  'but_emma_was': 1,
#  'emma_was_aware': 1,
#  'was_aware_that': 2,
#  'aware_that_great': 1,
#  'that_great_must': 1,
#  'be_the_difference': 1,
#  'the_difference_between': 14,
#  'difference_between_a': 6,
#  'between_a_mrs.': 1,
#  'a_mrs._weston': 1,
#  'mrs._weston_,': 73,
#  'weston_,_only': 1,
#  ',_only_half': 2,
#  'from_them_,': 41,
#  'and_a_miss': 1,
#  'a_miss_taylor': 1,
#  'miss_taylor_in': 1,
#  'taylor_in_the': 1,
#  'in_the_house': 189,
#  'the_house_;': 36,
#  'house_;_and': 42,
#  ';_and_with': 66,
#  'and_with_all': 43,
#  'with_all_her': 28,
#  'all_her_advantages': 1,
#  'her_advantages_,': 1,
#  'natural_and_domestic': 1,
#  'and_domestic_,': 1,
#  'domestic_,_she': 1,
#  ',_she_was': 98,
#  'she_was_now': 18,
#  'was_now_in': 8,
#  'now_in_great': 1,
#  'in_great_danger': 3,
#  'great_danger_of': 1,
#  'danger_of_suffering': 2,
#  'from_intellectual_solitude': 1,
#  'intellectual_solitude_.': 1,
#  'solitude_._she': 1,
#  '._she_dearly': 1,
#  'she_dearly_loved': 1,
#  'dearly_loved_her': 1,
#  'loved_her_father': 1,
#  'her_father_,': 53,
#  'father_,_but': 8,
#  ',_but_he': 146,
#  'was_no_companion': 1,
#  'no_companion_for': 1,
#  'companion_for_her': 2,
#  'her_._he': 9,
#  '._he_could': 30,
#  'he_could_not': 122,
#  'could_not_meet': 2,
#  'not_meet_her': 1,
#  'meet_her_in': 1,
#  'her_in_conversation': 2,
#  'in_conversation_,': 3,
#  'rational_or_playful': 1,
#  'or_playful_.': 1,
#  'the_evil_of': 14,
#  'evil_of_the': 8,
#  'of_the_actual': 2,
#  'the_actual_disparity': 1,
#  'actual_disparity_in': 1,
#  'disparity_in_their': 1,
#  'in_their_ages': 1,
#  'their_ages_(': 1,
#  'ages_(_and': 1,
#  '(_and_mr.': 2,
#  'and_mr._woodhouse': 8,
#  'mr._woodhouse_had': 7,
#  'not_married_early': 1,
#  'married_early_)': 1,
#  'early_)_was': 1,
#  ')_was_much': 1,
#  'was_much_increased': 2,
#  'much_increased_by': 3,
#  'increased_by_his': 1,
#  'by_his_constitution': 1,
#  'his_constitution_and': 1,
#  'constitution_and_habits': 1,
#  'and_habits_;': 2,
#  'for_having_been': 4,
#  'having_been_a': 5,
#  'been_a_valetudinarian': 1,
#  'a_valetudinarian_all': 1,
#  'valetudinarian_all_his': 1,
#  'all_his_life': 10,
#  'his_life_,': 25,
#  'life_,_without': 2,
#  ',_without_activity': 1,
#  'of_mind_or': 3,
#  'mind_or_body': 1,
#  'or_body_,': 1,
#  'body_,_he': 5,
#  ',_he_was': 169,
#  'he_was_a': 131,
#  'was_a_much': 3,
#  'a_much_older': 1,
#  'much_older_man': 1,
#  'older_man_in': 1,
#  'man_in_ways': 1,
#  'in_ways_than': 1,
#  'ways_than_in': 1,
#  'than_in_years': 1,
#  'in_years_;': 3,
#  'and_though_everywhere': 1,
#  'though_everywhere_beloved': 1,
#  'everywhere_beloved_for': 1,
#  'beloved_for_the': 2,
#  'for_the_friendliness': 1,
#  'the_friendliness_of': 2,
#  'friendliness_of_his': 2,
#  'of_his_heart': 16,
#  'and_his_amiable': 1,
#  'his_amiable_temper': 1,
#  'amiable_temper_,': 1,
#  'temper_,_his': 1,
#  ',_his_talents': 2,
#  'his_talents_could': 1,
#  'talents_could_not': 2,
#  'could_not_have': 50,
#  'not_have_recommended': 1,
#  'have_recommended_him': 1,
#  'at_any_time': 41,
#  'any_time_.': 5,
#  'her_sister_,': 41,
#  'sister_,_though': 1,
#  ',_though_comparatively': 1,
#  'though_comparatively_but': 1,
#  'comparatively_but_little': 1,
#  'but_little_removed': 1,
#  'little_removed_by': 1,
#  'removed_by_matrimony': 1,
#  'by_matrimony_,': 1,
#  'being_settled_in': 1,
#  'settled_in_london': 1,
#  'in_london_,': 23,
#  'london_,_only': 1,
#  ',_only_sixteen': 1,
#  'only_sixteen_miles': 1,
#  'sixteen_miles_off': 1,
#  'miles_off_,': 8,
#  'off_,_was': 1,
#  ',_was_much': 1,
#  'was_much_beyond': 1,
#  'her_daily_reach': 1,
#  'daily_reach_;': 1,
#  'reach_;_and': 2,
#  ';_and_many': 16,
#  'and_many_a': 22,
#  'many_a_long': 4,
#  'a_long_october': 1,
#  'long_october_and': 1,
#  'october_and_november': 1,
#  'and_november_evening': 1,
#  'november_evening_must': 1,
#  'be_struggled_through': 1,
#  'struggled_through_at': 1,
#  'through_at_hartfield': 1,
#  'at_hartfield_,': 28,
#  'hartfield_,_before': 2,
#  ',_before_christmas': 1,
#  'before_christmas_brought': 1,
#  'christmas_brought_the': 1,
#  'brought_the_next': 1,
#  'visit_from_isabella': 1,
#  'from_isabella_and': 1,
#  'isabella_and_her': 1,
#  'and_her_husband': 13,
#  'her_husband_,': 33,
#  'husband_,_and': 17,
#  ',_and_their': 258,
#  'and_their_little': 5,
#  'their_little_children': 1,
#  'little_children_,': 19,
#  'to_fill_the': 8,
#  'fill_the_house': 1,
#  'the_house_,': 176,
#  'house_,_and': 192,
#  ',_and_give': 67,
#  'and_give_her': 1,
#  'give_her_pleasant': 1,
#  'her_pleasant_society': 1,
#  'pleasant_society_again': 1,
#  'society_again_.': 1,
#  'highbury_,_the': 2,
#  ',_the_large': 5,
#  'the_large_and': 3,
#  'large_and_populous': 1,
#  'and_populous_village': 1,
#  'populous_village_,': 1,
#  'village_,_almost': 1,
#  ',_almost_amounting': 1,
#  'almost_amounting_to': 1,
#  'amounting_to_a': 1,
#  'to_a_town': 1,
#  'a_town_,': 2,
#  'to_which_hartfield': 1,
#  'which_hartfield_,': 1,
#  'hartfield_,_in': 2,
#  ',_in_spite': 44,
#  'in_spite_of': 92,
#  'spite_of_its': 2,
#  'of_its_separate': 1,
#  'its_separate_lawn': 1,
#  'separate_lawn_,': 1,
#  'lawn_,_and': 3,
#  ',_and_shrubberies': 1,
#  'and_shrubberies_,': 1,
#  'and_name_,': 2,
#  'name_,_did': 2,
#  ',_did_really': 1,
#  'did_really_belong': 1,
#  'really_belong_,': 1,
#  'belong_,_afforded': 1,
#  ',_afforded_her': 1,
#  'afforded_her_no': 2,
#  'her_no_equals': 1,
#  'no_equals_.': 1,
#  'equals_._the': 1,
#  '._the_woodhouses': 1,
#  'were_first_in': 1,
#  'first_in_consequence': 1,
#  'in_consequence_there': 1,
#  'consequence_there_.': 1,
#  'there_._all': 1,
#  '._all_looked': 1,
#  'all_looked_up': 1,
#  'looked_up_to': 7,
#  'up_to_them': 5,
#  'to_them_.': 41,
#  'them_._she': 13,
#  '._she_had': 91,
#  'many_acquaintance_in': 1,
#  'acquaintance_in_the': 4,
#  'in_the_place': 52,
#  'the_place_,': 32,
#  'place_,_for': 5,
#  ',_for_her': 15,
#  'for_her_father': 5,
#  'her_father_was': 11,
#  'father_was_universally': 1,
#  'was_universally_civil': 1,
#  'universally_civil_,': 1,
#  'but_not_one': 5,
#  'not_one_among': 2,
#  'one_among_them': 2,
#  'among_them_who': 1,
#  'them_who_could': 1,
#  'who_could_be': 6,
#  'could_be_accepted': 1,
#  'be_accepted_in': 1,
#  'accepted_in_lieu': 1,
#  'in_lieu_of': 3,
#  'lieu_of_miss': 1,
#  'taylor_for_even': 1,
#  'for_even_half': 1,
#  'even_half_a': 3,
#  'half_a_day': 3,
#  'a_day_.': 10,
#  'day_._it': 3,
#  'was_a_melancholy': 2,
#  'a_melancholy_change': 2,
#  'melancholy_change_;': 1,
#  'change_;_and': 3,
#  ';_and_emma': 20,
#  'could_not_but': 43,
#  'not_but_sigh': 1,
#  'but_sigh_over': 1,
#  'sigh_over_it': 1,
#  'over_it_,': 17,
#  'it_,_and': 441,
#  ',_and_wish': 9,
#  'and_wish_for': 3,
#  'wish_for_impossible': 1,
#  'for_impossible_things': 1,
#  'impossible_things_,': 1,
#  'till_her_father': 1,
#  'her_father_awoke': 1,
#  'father_awoke_,': 1,
#  'awoke_,_and': 5,
#  ',_and_made': 136,
#  'and_made_it': 11,
#  'made_it_necessary': 1,
#  'it_necessary_to': 7,
#  'necessary_to_be': 2,
#  'to_be_cheerful': 1,
#  'be_cheerful_.': 2,
#  'his_spirits_required': 1,
#  'spirits_required_support': 1,
#  'required_support_.': 1,
#  'support_._he': 1,
#  '._he_was': 243,
#  'was_a_nervous': 1,
#  'a_nervous_man': 2,
#  'nervous_man_,': 1,
#  'man_,_easily': 1,
#  ',_easily_depressed': 1,
#  'easily_depressed_;': 1,
#  'fond_of_every': 1,
#  'of_every_body': 11,
#  'every_body_that': 2,
#  'body_that_he': 1,
#  'that_he_was': 200,
#  'he_was_used': 3,
#  'was_used_to': 5,
#  'used_to_,': 4,
#  'to_,_and': 12,
#  ',_and_hating': 2,
#  'and_hating_to': 1,
#  'hating_to_part': 1,
#  'to_part_with': 18,
#  'part_with_them': 5,
#  'with_them_;': 21,
#  'hating_change_of': 1,
#  'change_of_every': 1,
#  'of_every_kind': 10,
#  'every_kind_.': 1,
#  'kind_._matrimony': 1,
#  '._matrimony_,': 1,
#  'matrimony_,_as': 1,
#  ',_as_the': 337,
#  'as_the_origin': 1,
#  'the_origin_of': 7,
#  'origin_of_change': 1,
#  'of_change_,': 2,
#  'was_always_disagreeable': 1,
#  'always_disagreeable_;': 1,
#  'disagreeable_;_and': 1,
#  ';_and_he': 405,
#  'and_he_was': 142,
#  'he_was_by': 14,
#  'was_by_no': 19,
#  'by_no_means': 67,
#  'no_means_yet': 1,
#  'means_yet_reconciled': 1,
#  'to_his_own': 45,
#  'his_own_daughter': 2,
#  "own_daughter_'s": 1,
#  "daughter_'s_marrying": 1,
#  "'s_marrying_,": 2,
#  'marrying_,_nor': 1,
#  ',_nor_could': 4,
#  'nor_could_ever': 1,
#  'could_ever_speak': 1,
#  'ever_speak_of': 1,
#  'speak_of_her': 6,
#  'of_her_but': 1,
#  'with_compassion_,': 5,
#  'compassion_,_though': 1,
#  ',_though_it': 45,
#  'though_it_had': 6,
#  'it_had_been': 81,
#  'had_been_entirely': 3,
#  'been_entirely_a': 1,
#  'entirely_a_match': 1,
#  'a_match_of': 1,
#  'match_of_affection': 1,
#  'of_affection_,': 3,
#  'when_he_was': 146,
#  'he_was_now': 18,
#  'was_now_obliged': 2,
#  'now_obliged_to': 2,
#  'obliged_to_part': 1,
#  'part_with_miss': 1,
#  'with_miss_taylor': 2,
#  'miss_taylor_too': 1,
#  'taylor_too_;': 1,
#  'too_;_and': 4,
#  ';_and_from': 47,
#  'his_habits_of': 1,
#  'habits_of_gentle': 1,
#  'of_gentle_selfishness': 1,
#  'gentle_selfishness_,': 1,
#  'selfishness_,_and': 2,
#  ',_and_of': 451,
#  'and_of_being': 2,
#  'of_being_never': 1,
#  'being_never_able': 1,
#  'never_able_to': 2,
#  'suppose_that_other': 1,
#  'that_other_people': 1,
#  'other_people_could': 1,
#  'people_could_feel': 1,
#  'could_feel_differently': 1,
#  'feel_differently_from': 1,
#  'differently_from_himself': 1,
#  'from_himself_,': 5,
#  'he_was_very': 35,
#  'was_very_much': 25,
#  'very_much_disposed': 3,
#  'much_disposed_to': 2,
#  'disposed_to_think': 4,
#  'to_think_miss': 1,
#  'think_miss_taylor': 1,
#  'taylor_had_done': 1,
#  'had_done_as': 1,
#  'done_as_sad': 1,
#  'a_thing_for': 4,
#  'thing_for_herself': 1,
#  'for_herself_as': 1,
#  'herself_as_for': 1,
#  'as_for_them': 3,
#  'for_them_,': 54,
#  'them_,_and': 556,
#  ',_and_would': 74,
#  'and_would_have': 20,
#  ...}

# %%
len(tri_dic.keys())
# Out:
# 1234365

# %%
# building bi_dictionary dictionary
# bi_dic contains the frequency for every two words in each sentence

bi_dic = {}

for token_sent in tokenized:
    
    m = len(token_sent) -1
    
    for i in range(m):

        bi = token_sent[i:i+2]

        
        bi = f'{bi[0]}_{bi[1]}'
        
        if bi in bi_dic.keys():
            bi_dic[bi] += 1

        else:
            bi_dic[bi] = 1

# %%
bi_dic
# Out:
# {'[_emma': 1,
#  'emma_by': 1,
#  'by_jane': 4,
#  'jane_austen': 3,
#  'austen_1816': 1,
#  '1816_]': 1,
#  'volume_i': 1,
#  'chapter_i': 9,
#  'emma_woodhouse': 4,
#  'woodhouse_,': 118,
#  ',_handsome': 8,
#  'handsome_,': 30,
#  ',_clever': 3,
#  'clever_,': 17,
#  ',_and': 38019,
#  'and_rich': 9,
#  'rich_,': 36,
#  ',_with': 1905,
#  'with_a': 1711,
#  'a_comfortable': 17,
#  'comfortable_home': 3,
#  'and_happy': 32,
#  'happy_disposition': 1,
#  'disposition_,': 20,
#  ',_seemed': 76,
#  'seemed_to': 386,
#  'to_unite': 4,
#  'unite_some': 1,
#  'some_of': 265,
#  'of_the': 18177,
#  'the_best': 268,
#  'best_blessings': 2,
#  'of_existence': 5,
#  'existence_;': 5,
#  ';_and': 6705,
#  'and_had': 220,
#  'had_lived': 16,
#  'lived_nearly': 1,
#  'nearly_twenty-one': 1,
#  'twenty-one_years': 1,
#  'years_in': 47,
#  'in_the': 9764,
#  'the_world': 813,
#  'with_very': 15,
#  'very_little': 86,
#  'little_to': 22,
#  'to_distress': 5,
#  'distress_or': 1,
#  'or_vex': 1,
#  'vex_her': 3,
#  'her_.': 500,
#  'she_was': 1051,
#  'was_the': 868,
#  'the_youngest': 24,
#  'youngest_of': 5,
#  'the_two': 430,
#  'two_daughters': 19,
#  'daughters_of': 66,
#  'of_a': 1906,
#  'a_most': 165,
#  'most_affectionate': 5,
#  'affectionate_,': 12,
#  'indulgent_father': 1,
#  'father_;': 59,
#  'had_,': 103,
#  ',_in': 2308,
#  'in_consequence': 14,
#  'consequence_of': 27,
#  'of_her': 1063,
#  'her_sister': 181,
#  "sister_'s": 85,
#  "'s_marriage": 15,
#  'marriage_,': 44,
#  'been_mistress': 3,
#  'mistress_of': 22,
#  'of_his': 2566,
#  'his_house': 180,
#  'house_from': 3,
#  'from_a': 208,
#  'a_very': 657,
#  'very_early': 24,
#  'early_period': 3,
#  'period_.': 5,
#  '._her': 157,
#  'her_mother': 230,
#  'had_died': 22,
#  'died_too': 1,
#  'too_long': 27,
#  'long_ago': 35,
#  'ago_for': 4,
#  'for_her': 385,
#  'her_to': 257,
#  'to_have': 683,
#  'have_more': 23,
#  'more_than': 526,
#  'than_an': 21,
#  'an_indistinct': 2,
#  'remembrance_of': 37,
#  'her_caresses': 1,
#  'caresses_;': 1,
#  'and_her': 468,
#  'her_place': 17,
#  'place_had': 3,
#  'had_been': 1203,
#  'been_supplied': 2,
#  'by_an': 64,
#  'an_excellent': 56,
#  'excellent_woman': 2,
#  'woman_as': 11,
#  'as_governess': 4,
#  'governess_,': 7,
#  ',_who': 1604,
#  'who_had': 372,
#  'had_fallen': 31,
#  'fallen_little': 1,
#  'little_short': 2,
#  'a_mother': 23,
#  'mother_in': 23,
#  'in_affection': 1,
#  'affection_.': 13,
#  'sixteen_years': 13,
#  'years_had': 10,
#  'had_miss': 3,
#  'miss_taylor': 44,
#  'taylor_been': 1,
#  'been_in': 94,
#  'in_mr.': 19,
#  'mr._woodhouse': 132,
#  "woodhouse_'s": 36,
#  "'s_family": 18,
#  'family_,': 101,
#  'less_as': 1,
#  'as_a': 940,
#  'a_governess': 2,
#  'governess_than': 1,
#  'than_a': 110,
#  'a_friend': 102,
#  'friend_,': 203,
#  ',_very': 163,
#  'very_fond': 27,
#  'fond_of': 108,
#  'of_both': 52,
#  'both_daughters': 1,
#  'daughters_,': 70,
#  'but_particularly': 4,
#  'particularly_of': 1,
#  'of_emma': 11,
#  'emma_.': 50,
#  '._between': 5,
#  'between__them_': 1,
#  '_them__it': 1,
#  'it_was': 2672,
#  'was_more': 84,
#  'more_the': 43,
#  'the_intimacy': 7,
#  'of_sisters': 2,
#  'sisters_.': 14,
#  '._even': 45,
#  'even_before': 13,
#  'before_miss': 4,
#  'taylor_had': 4,
#  'had_ceased': 13,
#  'ceased_to': 18,
#  'to_hold': 49,
#  'hold_the': 30,
#  'the_nominal': 2,
#  'office_of': 17,
#  'of_governess': 1,
#  ',_the': 5898,
#  'the_mildness': 2,
#  'mildness_of': 5,
#  'her_temper': 11,
#  'temper_had': 3,
#  'had_hardly': 16,
#  'hardly_allowed': 1,
#  'to_impose': 4,
#  'impose_any': 1,
#  'any_restraint': 2,
#  'restraint_;': 3,
#  'and_the': 8545,
#  'the_shadow': 65,
#  'shadow_of': 67,
#  'of_authority': 5,
#  'authority_being': 1,
#  'now_long': 1,
#  'long_passed': 2,
#  'passed_away': 25,
#  'away_,': 341,
#  ',_they': 1281,
#  'they_had': 647,
#  'been_living': 3,
#  'living_together': 2,
#  'together_as': 16,
#  'as_friend': 2,
#  'friend_and': 20,
#  'friend_very': 2,
#  'very_mutually': 2,
#  'mutually_attached': 1,
#  'attached_,': 3,
#  'and_emma': 67,
#  'emma_doing': 1,
#  'doing_just': 2,
#  'just_what': 28,
#  'what_she': 123,
#  'she_liked': 17,
#  'liked_;': 2,
#  'highly_esteeming': 1,
#  'esteeming_miss': 1,
#  "taylor_'s": 8,
#  "'s_judgment": 8,
#  'judgment_,': 72,
#  ',_but': 3039,
#  'but_directed': 1,
#  'directed_chiefly': 1,
#  'chiefly_by': 4,
#  'her_own': 379,
#  'own_.': 89,
#  'the_real': 71,
#  'real_evils': 1,
#  'evils_,': 11,
#  ',_indeed': 288,
#  'indeed_,': 360,
#  ',_of': 783,
#  "emma_'s": 79,
#  "'s_situation": 14,
#  'situation_were': 1,
#  'were_the': 229,
#  'the_power': 106,
#  'power_of': 116,
#  'of_having': 71,
#  'rather_too': 16,
#  'too_much': 175,
#  'much_her': 3,
#  'own_way': 37,
#  'way_,': 399,
#  'and_a': 1141,
#  'a_disposition': 8,
#  'disposition_to': 8,
#  'to_think': 259,
#  'think_a': 14,
#  'a_little': 897,
#  'too_well': 28,
#  'well_of': 39,
#  'of_herself': 31,
#  'herself_;': 55,
#  ';_these': 39,
#  'these_were': 110,
#  'the_disadvantages': 1,
#  'disadvantages_which': 1,
#  'which_threatened': 2,
#  'alloy_to': 1,
#  'to_her': 784,
#  'her_many': 7,
#  'many_enjoyments': 1,
#  'enjoyments_.': 2,
#  '._the': 1582,
#  'the_danger': 24,
#  'danger_,': 27,
#  ',_however': 439,
#  'however_,': 475,
#  ',_was': 736,
#  'was_at': 177,
#  'at_present': 83,
#  'so_unperceived': 1,
#  'unperceived_,': 1,
#  ',_that': 4941,
#  'that_they': 930,
#  'they_did': 152,
#  'did_not': 921,
#  'not_by': 55,
#  'by_any': 114,
#  'any_means': 23,
#  'means_rank': 1,
#  'rank_as': 3,
#  'as_misfortunes': 1,
#  'with_her': 508,
#  'sorrow_came': 1,
#  'came_--': 7,
#  '--_a': 244,
#  'a_gentle': 12,
#  'gentle_sorrow': 1,
#  'sorrow_--': 3,
#  '--_but': 365,
#  'but_not': 180,
#  'not_at': 137,
#  'at_all': 576,
#  'all_in': 107,
#  'the_shape': 47,
#  'shape_of': 45,
#  'of_any': 215,
#  'disagreeable_consciousness.': 1,
#  'consciousness._--': 1,
#  '--_miss': 18,
#  'taylor_married': 1,
#  'married_.': 27,
#  '._it': 1052,
#  'was_miss': 1,
#  "'s_loss": 5,
#  'loss_which': 1,
#  'which_first': 7,
#  'first_brought': 4,
#  'brought_grief': 1,
#  'grief_.': 7,
#  'was_on': 82,
#  'on_the': 2638,
#  'the_wedding-day': 1,
#  'of_this': 673,
#  'this_beloved': 1,
#  'beloved_friend': 1,
#  'friend_that': 5,
#  'that_emma': 25,
#  'emma_first': 2,
#  'first_sat': 1,
#  'sat_in': 42,
#  'in_mournful': 1,
#  'mournful_thought': 1,
#  'any_continuance': 1,
#  'continuance_.': 2,
#  'the_wedding': 12,
#  'wedding_over': 1,
#  'over_,': 148,
#  'the_bride-people': 1,
#  'bride-people_gone': 1,
#  'gone_,': 85,
#  'her_father': 255,
#  'father_and': 141,
#  'and_herself': 16,
#  'herself_were': 1,
#  'were_left': 32,
#  'left_to': 48,
#  'to_dine': 23,
#  'dine_together': 1,
#  'together_,': 291,
#  'with_no': 43,
#  'no_prospect': 1,
#  'a_third': 52,
#  'third_to': 3,
#  'to_cheer': 9,
#  'cheer_a': 1,
#  'a_long': 222,
#  'long_evening': 2,
#  'evening_.': 59,
#  'father_composed': 1,
#  'composed_himself': 1,
#  'to_sleep': 34,
#  'sleep_after': 1,
#  'after_dinner': 21,
#  'dinner_,': 60,
#  ',_as': 3155,
#  'as_usual': 41,
#  'usual_,': 38,
#  'and_she': 793,
#  'she_had': 1018,
#  'had_then': 17,
#  'then_only': 9,
#  'only_to': 123,
#  'to_sit': 81,
#  'and_think': 14,
#  'think_of': 226,
#  'of_what': 234,
#  'had_lost': 22,
#  'lost_.': 29,
#  'the_event': 39,
#  'event_had': 3,
#  'had_every': 11,
#  'every_promise': 1,
#  'promise_of': 27,
#  'of_happiness': 21,
#  'happiness_for': 2,
#  'her_friend': 80,
#  'friend_.': 88,
#  '._mr.': 111,
#  'mr._weston': 162,
#  'was_a': 1212,
#  'a_man': 1057,
#  'man_of': 291,
#  'of_unexceptionable': 1,
#  'unexceptionable_character': 1,
#  'character_,': 55,
#  ',_easy': 10,
#  'easy_fortune': 1,
#  'fortune_,': 60,
#  ',_suitable': 2,
#  'suitable_age': 1,
#  'age_,': 74,
#  'and_pleasant': 12,
#  'pleasant_manners': 1,
#  'manners_;': 3,
#  'and_there': 766,
#  'there_was': 1009,
#  'was_some': 29,
#  'some_satisfaction': 2,
#  'satisfaction_in': 15,
#  'in_considering': 2,
#  'with_what': 69,
#  'what_self-denying': 1,
#  'self-denying_,': 2,
#  ',_generous': 7,
#  'generous_friendship': 2,
#  'friendship_she': 1,
#  'had_always': 51,
#  'always_wished': 3,
#  'and_promoted': 2,
#  'promoted_the': 2,
#  'the_match': 20,
#  'match_;': 3,
#  ';_but': 2267,
#  'but_it': 449,
#  'a_black': 36,
#  'black_morning': 1,
#  "morning_'s": 15,
#  "'s_work": 33,
#  'work_for': 29,
#  'the_want': 18,
#  'want_of': 101,
#  'of_miss': 51,
#  'taylor_would': 1,
#  'would_be': 609,
#  'be_felt': 9,
#  'felt_every': 2,
#  'every_hour': 16,
#  'hour_of': 58,
#  'of_every': 193,
#  'every_day': 131,
#  'day_.': 336,
#  'she_recalled': 2,
#  'recalled_her': 1,
#  'her_past': 3,
#  'past_kindness': 2,
#  'kindness_--': 2,
#  '--_the': 349,
#  'the_kindness': 21,
#  'kindness_,': 36,
#  'the_affection': 11,
#  'affection_of': 7,
#  'of_sixteen': 1,
#  'years_--': 9,
#  '--_how': 86,
#  'how_she': 49,
#  'had_taught': 7,
#  'taught_and': 3,
#  'and_how': 197,
#  'had_played': 5,
#  'played_with': 6,
#  'her_from': 55,
#  'from_five': 2,
#  'years_old': 164,
#  'old_--': 2,
#  'had_devoted': 1,
#  'devoted_all': 2,
#  'all_her': 203,
#  'her_powers': 8,
#  'powers_to': 4,
#  'to_attach': 11,
#  'attach_and': 1,
#  'and_amuse': 3,
#  'her_in': 136,
#  'in_health': 7,
#  'health_--': 6,
#  '--_and': 552,
#  'how_nursed': 1,
#  'nursed_her': 2,
#  'her_through': 8,
#  'through_the': 620,
#  'the_various': 19,
#  'various_illnesses': 1,
#  'of_childhood': 4,
#  'childhood_.': 4,
#  '._a': 353,
#  'a_large': 121,
#  'large_debt': 1,
#  'debt_of': 1,
#  'of_gratitude': 9,
#  'gratitude_was': 1,
#  'was_owing': 4,
#  'owing_here': 1,
#  'here_;': 45,
#  'but_the': 1051,
#  'intercourse_of': 4,
#  'the_last': 356,
#  'last_seven': 1,
#  'seven_years': 46,
#  'years_,': 168,
#  'the_equal': 5,
#  'equal_footing': 2,
#  'footing_and': 1,
#  'and_perfect': 18,
#  'unreserve_which': 1,
#  'which_had': 212,
#  'had_soon': 10,
#  'soon_followed': 7,
#  'followed_isabella': 1,
#  "isabella_'s": 15,
#  ',_on': 405,
#  'on_their': 150,
#  'being_left': 8,
#  'to_each': 65,
#  'each_other': 224,
#  'other_,': 242,
#  'was_yet': 49,
#  'yet_a': 44,
#  'a_dearer': 1,
#  'dearer_,': 4,
#  ',_tenderer': 1,
#  'tenderer_recollection': 1,
#  'recollection_.': 6,
#  'been_a': 173,
#  'and_companion': 4,
#  'companion_such': 1,
#  'such_as': 194,
#  'as_few': 3,
#  'few_possessed': 1,
#  'possessed_:': 1,
#  ':_intelligent': 1,
#  'intelligent_,': 5,
#  'well-informed_,': 3,
#  ',_useful': 2,
#  'useful_,': 12,
#  ',_gentle': 6,
#  'gentle_,': 11,
#  ',_knowing': 32,
#  'knowing_all': 3,
#  'all_the': 3370,
#  'the_ways': 44,
#  'ways_of': 51,
#  'the_family': 166,
#  'interested_in': 19,
#  'in_all': 571,
#  'all_its': 48,
#  'its_concerns': 2,
#  'concerns_,': 7,
#  'and_peculiarly': 2,
#  'peculiarly_interested': 1,
#  'in_herself': 13,
#  'herself_,': 284,
#  'in_every': 171,
#  'every_pleasure': 1,
#  'pleasure_,': 59,
#  ',_every': 187,
#  'every_scheme': 1,
#  'scheme_of': 7,
#  'of_hers': 15,
#  'hers_--': 2,
#  '--_one': 33,
#  'one_to': 131,
#  'to_whom': 234,
#  'whom_she': 66,
#  'she_could': 489,
#  'could_speak': 10,
#  'every_thought': 7,
#  'thought_as': 7,
#  'as_it': 492,
#  'it_arose': 3,
#  'arose_,': 90,
#  'and_who': 183,
#  'had_such': 30,
#  'such_an': 184,
#  'an_affection': 9,
#  'affection_for': 26,
#  'as_could': 23,
#  'could_never': 50,
#  'never_find': 4,
#  'find_fault': 4,
#  'fault_.': 9,
#  'how_was': 17,
#  'was_she': 27,
#  'she_to': 28,
#  'to_bear': 74,
#  'bear_the': 59,
#  'the_change': 31,
#  'change_?': 2,
#  '?_--': 383,
#  '--_it': 184,
#  'was_true': 16,
#  'true_that': 20,
#  'that_her': 106,
#  'friend_was': 6,
#  'going_only': 2,
#  'only_half': 13,
#  'half_a': 108,
#  'a_mile': 47,
#  'mile_from': 10,
#  'from_them': 122,
#  'them_;': 408,
#  'but_emma': 19,
#  'emma_was': 62,
#  'was_aware': 7,
#  'aware_that': 15,
#  'that_great': 42,
#  'great_must': 1,
#  'be_the': 496,
#  'the_difference': 46,
#  'difference_between': 38,
#  'between_a': 14,
#  'a_mrs.': 5,
#  'mrs._weston': 249,
#  'weston_,': 112,
#  ',_only': 86,
#  'them_,': 2318,
#  'a_miss': 9,
#  'taylor_in': 1,
#  'the_house': 1409,
#  'house_;': 109,
#  'and_with': 720,
#  'with_all': 488,
#  'her_advantages': 1,
#  'advantages_,': 5,
#  'natural_and': 14,
#  'and_domestic': 6,
#  'domestic_,': 2,
#  ',_she': 977,
#  'was_now': 191,
#  'now_in': 73,
#  'in_great': 59,
#  'great_danger': 3,
#  'danger_of': 42,
#  'of_suffering': 7,
#  'from_intellectual': 1,
#  'intellectual_solitude': 1,
#  'solitude_.': 5,
#  '._she': 751,
#  'she_dearly': 2,
#  'dearly_loved': 2,
#  'loved_her': 24,
#  'father_,': 473,
#  'but_he': 651,
#  'was_no': 264,
#  'no_companion': 4,
#  'companion_for': 5,
#  '._he': 1591,
#  'he_could': 458,
#  'could_not': 1006,
#  'not_meet': 17,
#  'meet_her': 10,
#  'in_conversation': 9,
#  'conversation_,': 41,
#  'rational_or': 1,
#  'or_playful': 1,
#  'playful_.': 1,
#  'the_evil': 124,
#  'evil_of': 32,
#  'the_actual': 11,
#  'actual_disparity': 1,
#  'disparity_in': 1,
#  'in_their': 671,
#  'their_ages': 2,
#  'ages_(': 1,
#  '(_and': 48,
#  'and_mr.': 109,
#  'woodhouse_had': 8,
#  'not_married': 3,
#  'married_early': 1,
#  'early_)': 1,
#  ')_was': 8,
#  'was_much': 35,
#  'much_increased': 4,
#  'increased_by': 8,
#  'by_his': 288,
#  'his_constitution': 4,
#  'constitution_and': 1,
#  'and_habits': 4,
#  'habits_;': 5,
#  'for_having': 40,
#  'having_been': 48,
#  'a_valetudinarian': 1,
#  'valetudinarian_all': 1,
#  'all_his': 533,
#  'his_life': 140,
#  'life_,': 336,
#  ',_without': 294,
#  'without_activity': 1,
#  'of_mind': 94,
#  'mind_or': 4,
#  'or_body': 1,
#  'body_,': 143,
#  ',_he': 2789,
#  'he_was': 1967,
#  'a_much': 34,
#  'much_older': 2,
#  'older_man': 2,
#  'man_in': 153,
#  'in_ways': 1,
#  'ways_than': 1,
#  'than_in': 35,
#  'in_years': 7,
#  'years_;': 27,
#  'and_though': 169,
#  'though_everywhere': 2,
#  'everywhere_beloved': 1,
#  'beloved_for': 2,
#  'for_the': 2902,
#  'the_friendliness': 2,
#  'friendliness_of': 2,
#  'his_heart': 180,
#  'and_his': 1464,
#  'his_amiable': 3,
#  'amiable_temper': 2,
#  'temper_,': 30,
#  ',_his': 521,
#  'his_talents': 3,
#  'talents_could': 2,
#  'not_have': 264,
#  'have_recommended': 1,
#  'recommended_him': 4,
#  'at_any': 118,
#  'any_time': 48,
#  'time_.': 237,
#  'sister_,': 143,
#  ',_though': 761,
#  'though_comparatively': 1,
#  'comparatively_but': 1,
#  'but_little': 20,
#  'little_removed': 1,
#  'removed_by': 3,
#  'by_matrimony': 1,
#  'matrimony_,': 3,
#  'being_settled': 4,
#  'settled_in': 15,
#  'in_london': 42,
#  'london_,': 65,
#  'only_sixteen': 1,
#  'sixteen_miles': 6,
#  'miles_off': 16,
#  'off_,': 222,
#  'much_beyond': 11,
#  'her_daily': 1,
#  'daily_reach': 1,
#  'reach_;': 3,
#  'and_many': 123,
#  'many_a': 141,
#  'long_october': 1,
#  'october_and': 1,
#  'and_november': 1,
#  'november_evening': 1,
#  'evening_must': 1,
#  'be_struggled': 1,
#  'struggled_through': 1,
#  'through_at': 2,
#  'at_hartfield': 67,
#  'hartfield_,': 56,
#  ',_before': 191,
#  'before_christmas': 2,
#  'christmas_brought': 1,
#  'brought_the': 64,
#  'the_next': 292,
#  'visit_from': 8,
#  'from_isabella': 2,
#  'isabella_and': 16,
#  'her_husband': 157,
#  'husband_,': 68,
#  'and_their': 540,
#  'their_little': 24,
#  'little_children': 35,
#  'children_,': 248,
#  'to_fill': 36,
#  'fill_the': 26,
#  'house_,': 614,
#  'and_give': 100,
#  'give_her': 67,
#  'her_pleasant': 4,
#  'pleasant_society': 1,
#  'society_again': 1,
#  'again_.': 354,
#  'highbury_,': 41,
#  'the_large': 40,
#  'large_and': 27,
#  'and_populous': 3,
#  'populous_village': 1,
#  'village_,': 34,
#  ',_almost': 59,
#  'almost_amounting': 1,
#  'amounting_to': 3,
#  'to_a': 581,
#  'a_town': 7,
#  'town_,': 76,
#  'to_which': 90,
#  'which_hartfield': 1,
#  'in_spite': 104,
#  'spite_of': 111,
#  'of_its': 187,
#  'its_separate': 1,
#  'separate_lawn': 1,
#  'lawn_,': 7,
#  'and_shrubberies': 2,
#  'shrubberies_,': 4,
#  'and_name': 3,
#  'name_,': 211,
#  ',_did': 161,
#  'did_really': 4,
#  'really_belong': 2,
#  'belong_,': 3,
#  ',_afforded': 2,
#  'afforded_her': 7,
#  'her_no': 16,
#  'no_equals': 1,
#  'equals_.': 2,
#  'the_woodhouses': 3,
#  'were_first': 5,
#  'first_in': 24,
#  'consequence_there': 1,
#  'there_.': 215,
#  '._all': 155,
#  'all_looked': 9,
#  'looked_up': 69,
#  'up_to': 461,
#  'to_them': 425,
#  'them_.': 1217,
#  'many_acquaintance': 3,
#  'acquaintance_in': 8,
#  'the_place': 317,
#  'place_,': 321,
#  ',_for': 1441,
#  'father_was': 36,
#  'was_universally': 2,
#  'universally_civil': 1,
#  'civil_,': 9,
#  'not_one': 113,
#  'one_among': 5,
#  'among_them': 179,
#  'them_who': 22,
#  'who_could': 67,
#  'could_be': 316,
#  'be_accepted': 12,
#  'accepted_in': 4,
#  'in_lieu': 3,
#  'lieu_of': 3,
#  'taylor_for': 1,
#  'for_even': 25,
#  'even_half': 3,
#  'a_day': 160,
#  'a_melancholy': 14,
#  'melancholy_change': 2,
#  'change_;': 9,
#  'not_but': 64,
#  'but_sigh': 1,
#  'sigh_over': 1,
#  'over_it': 53,
#  'it_,': 1929,
#  'and_wish': 12,
#  'wish_for': 26,
#  'for_impossible': 1,
#  'impossible_things': 1,
#  'things_,': 325,
#  'till_her': 14,
#  'father_awoke': 1,
#  'awoke_,': 7,
#  'and_made': 185,
#  'made_it': 63,
#  'it_necessary': 13,
#  'necessary_to': 42,
#  'to_be': 3357,
#  'be_cheerful': 4,
#  'cheerful_.': 6,
#  'his_spirits': 19,
#  'spirits_required': 1,
#  'required_support': 1,
#  'support_.': 6,
#  'a_nervous': 8,
#  'nervous_man': 2,
#  'man_,': 975,
#  ',_easily': 3,
#  'easily_depressed': 1,
#  'depressed_;': 1,
#  'every_body': 143,
#  'body_that': 7,
#  'that_he': 1893,
#  'was_used': 8,
#  'used_to': 175,
#  'to_,': 105,
#  'and_hating': 2,
#  'hating_to': 1,
#  'to_part': 32,
#  'part_with': 24,
#  'with_them': 429,
#  'hating_change': 1,
#  'change_of': 35,
#  'every_kind': 17,
#  'kind_.': 28,
#  '._matrimony': 1,
#  'as_the': 1396,
#  'the_origin': 9,
#  'origin_of': 9,
#  'of_change': 4,
#  'change_,': 32,
#  'was_always': 71,
#  'always_disagreeable': 1,
#  'disagreeable_;': 2,
#  'and_he': 3488,
#  'was_by': 73,
#  'by_no': 91,
#  'no_means': 75,
#  'means_yet': 1,
#  'yet_reconciled': 1,
#  'to_his': 982,
#  'his_own': 749,
#  'own_daughter': 3,
#  "daughter_'s": 34,
#  "'s_marrying": 11,
#  'marrying_,': 6,
#  ',_nor': 895,
#  'nor_could': 18,
#  'could_ever': 15,
#  'ever_speak': 1,
#  'speak_of': 71,
#  'her_but': 4,
#  'with_compassion': 8,
#  'compassion_,': 17,
#  'though_it': 93,
#  'it_had': 264,
#  'been_entirely': 8,
#  'entirely_a': 2,
#  'a_match': 18,
#  'match_of': 1,
#  'of_affection': 10,
#  'affection_,': 38,
#  'when_he': 1048,
#  'now_obliged': 2,
#  'obliged_to': 161,
#  'with_miss': 22,
#  'taylor_too': 1,
#  'too_;': 30,
#  'and_from': 330,
#  'his_habits': 6,
#  'habits_of': 13,
#  'of_gentle': 5,
#  'gentle_selfishness': 1,
#  'selfishness_,': 4,
#  'and_of': 842,
#  'of_being': 214,
#  'being_never': 2,
#  'never_able': 2,
#  'able_to': 331,
#  'suppose_that': 32,
#  'that_other': 20,
#  'other_people': 43,
#  'people_could': 6,
#  'could_feel': 8,
#  'feel_differently': 1,
#  'differently_from': 1,
#  'from_himself': 10,
#  'himself_,': 350,
#  'was_very': 274,
#  'very_much': 228,
#  'much_disposed': 3,
#  'disposed_to': 34,
#  'think_miss': 3,
#  'had_done': 160,
#  'done_as': 11,
#  'as_sad': 1,
#  'a_thing': 158,
#  'thing_for': 33,
#  'for_herself': 39,
#  'herself_as': 11,
#  'as_for': 240,
#  'for_them': 240,
#  'and_would': 98,
#  'would_have': 505,
#  'have_been': 927,
#  'a_great': 798,
#  'great_deal': 165,
#  'happier_if': 2,
#  'if_she': 161,
#  'had_spent': 13,
#  'spent_all': 5,
#  'the_rest': 448,
#  'rest_of': 216,
#  'her_life': 42,
#  'life_at': 4,
#  'hartfield_.': 26,
#  'emma_smiled': 3,
#  'smiled_and': 7,
#  'and_chatted': 1,
#  'chatted_as': 1,
#  'as_cheerfully': 1,
#  'cheerfully_as': 1,
#  'as_she': 482,
#  'could_,': 72,
#  ',_to': 2675,
#  'to_keep': 194,
#  'keep_him': 18,
#  'from_such': 21,
#  'such_thoughts': 2,
#  'thoughts_;': 10,
#  'but_when': 236,
#  'when_tea': 2,
#  'tea_came': 1,
#  'came_,': 131,
#  ',_it': 1292,
#  'was_impossible': 41,
#  'impossible_for': 26,
#  'for_him': 379,
#  'not_to': 563,
#  'to_say': 500,
#  'say_exactly': 2,
#  'exactly_as': 16,
#  'as_he': 995,
#  'he_had': 1864,
#  'had_said': 92,
#  'said_at': 12,
#  'at_dinner': 19,
#  ...}

# %%
# building tri-gram dictionary model 
#trigram_dic contains all possible third words and theirs probability based on the frequency of the two words before.


trigram_dic = {}

for key in tri_dic.keys():
    
    k = key.split('_')
    
    b = f"{k[0]}_{k[1]}"

    try:
        prob = tri_dic[key]/bi_dic[b]
    except Exception as e:
#         print(e)
        pass
        
    
    if b in trigram_dic.keys():
        trigram_dic[b][k[2]] = prob
        
        
    else:
        trigram_dic[b] = {k[2]:prob}

# %%
len(trigram_dic.keys())
# Out:
# 486844

# %%
trigram_dic
# Out:
# {'[_emma': {'by': 1.0},
#  'emma_by': {'jane': 1.0},
#  'by_jane': {'austen': 0.75, 'herself': 0.25},
#  'jane_austen': {'1816': 0.3333333333333333,
#   '1818': 0.3333333333333333,
#   '1811': 0.3333333333333333},
#  'austen_1816': {']': 1.0},
#  'emma_woodhouse': {',': 1.0},
#  'woodhouse_,': {'handsome': 0.00847457627118644,
#   'if': 0.00847457627118644,
#   'and': 0.0423728813559322,
#   'understanding': 0.00847457627118644,
#   'full': 0.00847457627118644,
#   'he': 0.01694915254237288,
#   'is': 0.00847457627118644,
#   'to': 0.01694915254237288,
#   'do': 0.025423728813559324,
#   'tell': 0.00847457627118644,
#   'as': 0.025423728813559324,
#   'who': 0.059322033898305086,
#   "''": 0.06779661016949153,
#   'what': 0.03389830508474576,
#   'that': 0.01694915254237288,
#   'shaking': 0.00847457627118644,
#   'always': 0.01694915254237288,
#   'a': 0.025423728813559324,
#   'his': 0.00847457627118644,
#   'so': 0.01694915254237288,
#   'i': 0.059322033898305086,
#   'you': 0.059322033898305086,
#   'there': 0.00847457627118644,
#   'ours': 0.00847457627118644,
#   'must': 0.00847457627118644,
#   'rather': 0.00847457627118644,
#   'how': 0.0423728813559322,
#   '(': 0.00847457627118644,
#   'one': 0.01694915254237288,
#   'every': 0.00847457627118644,
#   'of': 0.00847457627118644,
#   'she': 0.00847457627118644,
#   'not': 0.00847457627118644,
#   'miss': 0.00847457627118644,
#   'believe': 0.00847457627118644,
#   'seemed': 0.00847457627118644,
#   'we': 0.00847457627118644,
#   'or': 0.00847457627118644,
#   'for': 0.01694915254237288,
#   'but': 0.00847457627118644,
#   'whom': 0.00847457627118644,
#   'it': 0.00847457627118644,
#   'our': 0.00847457627118644,
#   'this': 0.00847457627118644},
#  ',_handsome': {',': 0.625, 'letter': 0.125, '?': 0.125, 'as': 0.125},
#  'handsome_,': {'clever': 0.03333333333333333,
#   'rich': 0.03333333333333333,
#   'his': 0.03333333333333333,
#   'elegant': 0.03333333333333333,
#   'i': 0.06666666666666667,
#   'and': 0.16666666666666666,
#   'had': 0.03333333333333333,
#   'with': 0.03333333333333333,
#   'in': 0.03333333333333333,
#   'till': 0.03333333333333333,
#   'elinor': 0.03333333333333333,
#   'her': 0.03333333333333333,
#   'received': 0.03333333333333333,
#   'very': 0.03333333333333333,
#   'well-bred-looking': 0.03333333333333333,
#   'more': 0.03333333333333333,
#   'but': 0.03333333333333333,
#   'proud': 0.03333333333333333,
#   'strong': 0.03333333333333333},
#  ',_clever': {',': 0.3333333333333333,
#   'creature': 0.3333333333333333,
#   'as': 0.3333333333333333},
#  'clever_,': {'and': 0.17647058823529413,
#   'but': 0.11764705882352941,
#   'shewed': 0.058823529411764705,
#   'or': 0.058823529411764705,
#   'be': 0.058823529411764705,
#   'insinuating': 0.058823529411764705,
#   'for': 0.058823529411764705,
#   'especially': 0.058823529411764705,
#   'he': 0.058823529411764705,
#   'good': 0.058823529411764705},
#  ',_and': {'rich': 0.00010521055261842763,
#   'emma': 0.0004208422104737105,
#   'a': 0.013125016439148847,
#   'the': 0.08351087614087693,
#   'she': 0.007338436045135327,
#   'peculiarly': 2.6302638154606906e-05,
#   'who': 0.0020779084142139455,
#   'their': 0.006786080643888582,
#   'give': 0.0017622767563586627,
#   'shrubberies': 2.6302638154606906e-05,
#   'wish': 0.00023672374339146217,
#   'made': 0.0035771587890265394,
#   'hating': 5.260527630921381e-05,
#   'of': 0.011862489807727715,
#   'would': 0.001946395223440911,
#   'bear': 0.0004208422104737105,
#   'they': 0.014256029879796944,
#   'be': 0.00510271180199374,
#   'at': 0.003077408664089008,
#   'now': 0.001709671480049449,
#   'animated': 5.260527630921381e-05,
#   'hardly': 0.00013151319077303454,
#   'borrowed': 2.6302638154606906e-05,
#   'given': 0.00047344748678292435,
#   'smoothed': 2.6302638154606906e-05,
#   'break': 0.000289329019700676,
#   'has': 0.0006049606775559589,
#   'this': 0.0021042110523685526,
#   'i': 0.021147321076303953,
#   'help': 0.00015781582892764143,
#   'born': 5.260527630921381e-05,
#   'had': 0.004024303637654857,
#   'miss': 0.0004997501249375312,
#   'with': 0.01070517372892501,
#   'it': 0.007338436045135327,
#   'his': 0.01614981982692864,
#   'to': 0.019648070701491358,
#   'obtained': 5.260527630921381e-05,
#   'must': 0.0004997501249375312,
#   'governed': 2.6302638154606906e-05,
#   ',': 0.008390541571319604,
#   'he': 0.020963202609221705,
#   'energy': 2.6302638154606906e-05,
#   'in': 0.013993003498250875,
#   'when': 0.0026565664536152976,
#   'large': 7.890791446382072e-05,
#   'mrs.': 0.0003419342960098898,
#   'was': 0.006891291196507009,
#   'her': 0.004155816828427891,
#   'surrounded': 2.6302638154606906e-05,
#   'scramble': 5.260527630921381e-05,
#   'win': 2.6302638154606906e-05,
#   'very': 0.001157316078802704,
#   'fair': 0.00013151319077303454,
#   'quite': 0.000289329019700676,
#   'so': 0.003629764065335753,
#   'all': 0.019779583892264394,
#   'residing': 2.6302638154606906e-05,
#   'introduce': 5.260527630921381e-05,
#   'certainly': 0.00013151319077303454,
#   'powers': 7.890791446382072e-05,
#   'forming': 7.890791446382072e-05,
#   'for': 0.008522054762092638,
#   'on': 0.0034456455982535047,
#   'actually': 0.00010521055261842763,
#   'only': 0.0010521055261842763,
#   'describe': 5.260527630921381e-05,
#   'that': 0.012178121465582998,
#   'understood': 0.00018411846708224835,
#   'therefore': 0.0011047108024934901,
#   'asked': 0.000841684420947421,
#   'some': 0.0010521055261842763,
#   'my': 0.0044451458481285675,
#   'if': 0.0015781582892764145,
#   'you': 0.0029721981114705807,
#   'after': 0.0016307635655856282,
#   'thinking': 0.00018411846708224835,
#   'look': 0.0005260527630921381,
#   'situation': 5.260527630921381e-05,
#   'gentle': 7.890791446382072e-05,
#   'said': 0.01685999105710303,
#   'agreeing': 2.6302638154606906e-05,
#   'sometimes': 0.0003682369341644967,
#   'remember': 0.00023672374339146217,
#   'looks': 0.00010521055261842763,
#   'isabella': 5.260527630921381e-05,
#   'might': 0.0003682369341644967,
#   'praised': 0.00015781582892764143,
#   'receiving': 7.890791446382072e-05,
#   'attempted': 2.6302638154606906e-05,
#   'water-colours': 2.6302638154606906e-05,
#   'ought': 5.260527630921381e-05,
#   'again': 0.0003419342960098898,
#   'vowed': 5.260527630921381e-05,
#   'afraid': 2.6302638154606906e-05,
#   'request': 2.6302638154606906e-05,
#   'lessen': 5.260527630921381e-05,
#   'considerably': 2.6302638154606906e-05,
#   'accompanied': 5.260527630921381e-05,
#   'defended': 5.260527630921381e-05,
#   'mr.': 0.0007364738683289934,
#   'will': 0.005733975117704306,
#   'study': 2.6302638154606906e-05,
#   'sooner': 2.6302638154606906e-05,
#   'gone': 0.00026302638154606907,
#   'contained': 2.6302638154606906e-05,
#   'yet': 0.0017359741182040559,
#   'older': 5.260527630921381e-05,
#   'stood': 0.0015255530129672007,
#   'have': 0.005786580394013519,
#   'can': 0.0006575659538651726,
#   'sealed': 0.00015781582892764143,
#   'sent': 0.0015255530129672007,
#   'harriet': 0.00015781582892764143,
#   'gradually': 7.890791446382072e-05,
#   'sat': 0.0013677371840395591,
#   'speaking': 0.00021042110523685525,
#   'from': 0.0049448959730660986,
#   'altogether': 0.00021042110523685525,
#   'as': 0.005707672479549699,
#   'does': 0.00015781582892764143,
#   'supposing': 2.6302638154606906e-05,
#   'such': 0.0009468949735658487,
#   'happy': 0.00015781582892764143,
#   'teach': 0.000289329019700676,
#   'good-humour': 2.6302638154606906e-05,
#   'tried': 0.00047344748678292435,
#   'plans': 2.6302638154606906e-05,
#   'meeting': 2.6302638154606906e-05,
#   'found': 0.0017359741182040559,
#   'not': 0.006102212051868803,
#   'told': 0.0015781582892764145,
#   'rode': 2.6302638154606906e-05,
#   'being': 0.00047344748678292435,
#   'sighed': 5.260527630921381e-05,
#   'ornamented': 5.260527630921381e-05,
#   'pushing': 7.890791446382072e-05,
#   'could': 0.001157316078802704,
#   'then': 0.007943396722691285,
#   'saying': 0.0005523554012467451,
#   'confirm': 0.00010521055261842763,
#   'remembered': 0.00013151319077303454,
#   'believe': 0.00021042110523685525,
#   'hope': 0.00015781582892764143,
#   'sends': 2.6302638154606906e-05,
#   'staid': 5.260527630921381e-05,
#   'let': 0.005812883032168126,
#   'there': 0.005786580394013519,
#   'especially': 0.0004471448486283174,
#   'appear': 5.260527630921381e-05,
#   'we': 0.003787579894263395,
#   'two': 0.001420342460348773,
#   'smiled.': 2.6302638154606906e-05,
#   'say': 0.0029458954733159737,
#   'tosses': 2.6302638154606906e-05,
#   'just': 0.0003682369341644967,
#   'examined': 5.260527630921381e-05,
#   'replacing': 2.6302638154606906e-05,
#   'replied': 0.00013151319077303454,
#   'sour': 2.6302638154606906e-05,
#   'always': 0.000289329019700676,
#   'tottering': 2.6302638154606906e-05,
#   'stooping': 5.260527630921381e-05,
#   'talk': 7.890791446382072e-05,
#   'dexterously': 2.6302638154606906e-05,
#   'acknowledged': 2.6302638154606906e-05,
#   'ask': 0.00026302638154606907,
#   'variously': 2.6302638154606906e-05,
#   'sleeping': 2.6302638154606906e-05,
#   'respectable': 2.6302638154606906e-05,
#   'generally': 7.890791446382072e-05,
#   'gave': 0.003156316578552829,
#   'playing': 2.6302638154606906e-05,
#   '': 2.6302638154606906e-05,
#   'by': 0.003629764065335753,
#   '``': 0.00018411846708224835,
#   'whose': 0.0006049606775559589,
#   'take': 0.0024724479865330493,
#   'others': 0.00021042110523685525,
#   'passed': 0.0007627765064836003,
#   'talking': 0.00013151319077303454,
#   'out': 0.0014729477366579868,
#   'raise': 0.00021042110523685525,
#   'seemed': 0.0008153817827928141,
#   'secured': 0.00013151319077303454,
#   'leave': 0.0005523554012467451,
#   'one': 0.0022357242431415873,
#   'ascertain': 2.6302638154606906e-05,
#   'nothing': 0.0005523554012467451,
#   'set': 0.002840684920697546,
#   'too': 0.00031563165785528286,
#   'encounter': 2.6302638154606906e-05,
#   'keep': 0.0012625266314211315,
#   'may': 0.0003419342960098898,
#   'wrapped': 0.00018411846708224835,
#   'smiling': 2.6302638154606906e-05,
#   'prevent': 5.260527630921381e-05,
#   'people': 0.00015781582892764143,
#   'pleasures': 5.260527630921381e-05,
#   'solicitously': 2.6302638154606906e-05,
#   'seated': 5.260527630921381e-05,
#   'is': 0.0026302638154606906,
#   'kept': 0.0004471448486283174,
#   'know': 0.00047344748678292435,
#   'no': 0.002051605776059339,
#   'felt': 0.000578658039401352,
#   'giving': 0.00015781582892764143,
#   'opened': 0.0003419342960098898,
#   'little': 0.00023672374339146217,
#   'having': 0.00047344748678292435,
#   'resolved': 0.00010521055261842763,
#   'left': 0.0011836187169573108,
#   'avoiding': 2.6302638154606906e-05,
#   'return': 0.00023672374339146217,
#   'saw': 0.0024724479865330493,
#   'repressing': 2.6302638154606906e-05,
#   'endeavour': 2.6302638154606906e-05,
#   'shewed': 0.0003682369341644967,
#   'maintained': 5.260527630921381e-05,
#   'make': 0.0030248033877797943,
#   'begins': 5.260527630921381e-05,
#   'making': 0.0003419342960098898,
#   'selfish': 7.890791446382072e-05,
#   'easily': 2.6302638154606906e-05,
#   'fancying': 7.890791446382072e-05,
#   'without': 0.0009731976117204555,
#   'settle': 5.260527630921381e-05,
#   'what': 0.0022357242431415873,
#   'how': 0.0018674873089770904,
#   'since': 0.00013151319077303454,
#   'here': 0.00039453957231910363,
#   'write': 0.00039453957231910363,
#   'looking': 0.0006838685920197796,
#   'warm-hearted': 2.6302638154606906e-05,
#   'been': 0.00018411846708224835,
#   'spared': 2.6302638154606906e-05,
#   'less': 0.00010521055261842763,
#   'nobody': 0.0003682369341644967,
#   'merit': 2.6302638154606906e-05,
#   'resolving': 2.6302638154606906e-05,
#   'lament': 0.00015781582892764143,
#   'every': 0.003787579894263395,
#   'returned': 0.0007101712301743865,
#   'wishing': 7.890791446382072e-05,
#   'eaten': 5.260527630921381e-05,
#   'full': 0.00026302638154606907,
#   'jane': 0.00015781582892764143,
#   'handed': 5.260527630921381e-05,
#   'says': 5.260527630921381e-05,
#   'runs': 5.260527630921381e-05,
#   'grandmama': 5.260527630921381e-05,
#   'took': 0.0038401851705726084,
#   'haberdasher': 2.6302638154606906e-05,
#   'did': 0.0027091717299245113,
#   'perfectly': 2.6302638154606906e-05,
#   'defying': 2.6302638154606906e-05,
#   'furniture': 5.260527630921381e-05,
#   'feelings': 2.6302638154606906e-05,
#   'call': 0.0003682369341644967,
#   'slime': 2.6302638154606906e-05,
#   'haran': 0.00010521055261842763,
#   'lot': 0.00010521055261842763,
#   'sarai': 2.6302638154606906e-05,
#   'curse': 0.00010521055261842763,
#   'hai': 2.6302638154606906e-05,
#   'commended': 5.260527630921381e-05,
#   'menservants': 0.00010521055261842763,
#   'maidservants': 7.890791446382072e-05,
#   'herds': 7.890791446382072e-05,
#   'beheld': 0.000289329019700676,
#   'pitched': 0.0013151319077303453,
#   'southward': 7.890791446382072e-05,
#   'eastward': 7.890791446382072e-05,
#   'westward': 7.890791446382072e-05,
#   'built': 0.0004208422104737105,
#   'tidal': 2.6302638154606906e-05,
#   'shemeber': 2.6302638154606906e-05,
#   'smote': 0.0016570662037402352,
#   'also': 0.0013414345458849523,
#   'amraphel': 2.6302638154606906e-05,
#   'arioch': 5.260527630921381e-05,
#   'departed': 0.0005260527630921381,
#   'pursued': 0.00026302638154606907,
#   'kings': 0.00010521055261842763,
#   'ishmael': 0.00010521055261842763,
#   'bought': 7.890791446382072e-05,
#   'wash': 0.00023672374339146217,
#   'rest': 7.890791446382072e-05,
#   ...},
#  'and_rich': {',': 0.1111111111111111,
#   '.': 0.1111111111111111,
#   'to': 0.1111111111111111,
#   'houses': 0.1111111111111111,
#   ';': 0.1111111111111111,
#   'banners': 0.1111111111111111,
#   'prey': 0.1111111111111111,
#   'republics': 0.1111111111111111},
#  'rich_,': {'with': 0.027777777777777776,
#   'and': 0.25,
#   'nor': 0.027777777777777776,
#   'just': 0.027777777777777776,
#   'was': 0.027777777777777776,
#   'to': 0.027777777777777776,
#   'neither': 0.027777777777777776,
#   'when': 0.027777777777777776,
#   'yet': 0.05555555555555555,
#   'shall': 0.027777777777777776,
#   'i': 0.027777777777777776,
#   'ye': 0.027777777777777776,
#   'in': 0.027777777777777776,
#   'very': 0.027777777777777776,
#   'living': 0.027777777777777776,
#   'but': 0.027777777777777776,
#   'if': 0.027777777777777776,
#   'he': 0.027777777777777776,
#   'mottled': 0.027777777777777776,
#   'appeared': 0.027777777777777776,
#   'not': 0.027777777777777776,
#   'then': 0.027777777777777776,
#   'hemm': 0.027777777777777776},
#  ',_with': {'a': 0.1973753280839895,
#   'no': 0.005774278215223097,
#   'the': 0.13910761154855644,
#   'these': 0.002099737532808399,
#   'every': 0.004724409448818898,
#   'an': 0.029396325459317585,
#   'thorough': 0.0005249343832020997,
#   'such': 0.010498687664041995,
#   'all': 0.05301837270341207,
#   'most': 0.002099737532808399,
#   'mr.': 0.0010498687664041995,
#   'only': 0.003674540682414698,
#   'sentiments': 0.0005249343832020997,
#   'half': 0.0005249343832020997,
#   'some': 0.010498687664041995,
#   'probably': 0.0005249343832020997,
#   'miss': 0.0015748031496062992,
#   'explanations': 0.0005249343832020997,
#   'his': 0.046719160104986876,
#   'less': 0.0015748031496062992,
#   'nothing': 0.0026246719160104987,
#   'your': 0.007874015748031496,
#   'scarcely': 0.0010498687664041995,
#   'triumph': 0.0010498687664041995,
#   'its': 0.011023622047244094,
#   'self-interest': 0.0005249343832020997,
#   'smooth': 0.0005249343832020997,
#   'harsh': 0.0005249343832020997,
#   'trusting': 0.0005249343832020997,
#   'eyes': 0.0015748031496062992,
#   'oh': 0.0005249343832020997,
#   'variations': 0.0010498687664041995,
#   'another': 0.0005249343832020997,
#   'tears': 0.002099737532808399,
#   'closed': 0.0005249343832020997,
#   'serenity': 0.0005249343832020997,
#   'fiery': 0.0005249343832020997,
#   'sleek': 0.0005249343832020997,
#   'grating': 0.0005249343832020997,
#   'something': 0.0005249343832020997,
#   'letters': 0.0005249343832020997,
#   'red': 0.0005249343832020997,
#   'frantic': 0.0010498687664041995,
#   'crossed': 0.0005249343832020997,
#   'curling': 0.0005249343832020997,
#   'civility': 0.0005249343832020997,
#   'brows': 0.0005249343832020997,
#   'blazing': 0.0005249343832020997,
#   'lean': 0.0005249343832020997,
#   'towering': 0.0005249343832020997,
#   'ringing': 0.0010498687664041995,
#   'inhuman': 0.0005249343832020997,
#   'staring': 0.0005249343832020997,
#   'steady': 0.0010498687664041995,
#   'politeness': 0.0005249343832020997,
#   'hard': 0.0005249343832020997,
#   'parted': 0.0005249343832020997,
#   'violence': 0.0005249343832020997,
#   'quite': 0.0010498687664041995,
#   'cheerful': 0.0005249343832020997,
#   'slight': 0.0005249343832020997,
#   'rolling': 0.0005249343832020997,
#   'composure': 0.0010498687664041995,
#   'stern': 0.0010498687664041995,
#   'mock': 0.0005249343832020997,
# ...
#   'it': 0.021739130434782608,
#   'their': 0.021739130434782608},
#  'this_is': {'three': 0.0014771048744460858,
#   'the': 0.3515509601181684,
#   'a': 0.09748892171344166,
#   'feeling': 0.0014771048744460858,
#   'saying': 0.0014771048744460858,
#   'an': 0.01624815361890694,
#   'just': 0.0029542097488921715,
#   'most': 0.005908419497784343,
#   'quite': 0.0103397341211226,
#   'great': 0.0014771048744460858,
#   'too': 0.007385524372230428,
#   'coming': 0.0014771048744460858,
#   'like': 0.0029542097488921715,
#   'what': 0.01772525849335303,
#   'in': 0.0014771048744460858,
#   'not': 0.0413589364844904,
#   'living': 0.0014771048744460858,
#   'very': 0.014771048744460856,
#   'by': 0.0014771048744460858,
#   'precisely': 0.0029542097488921715,
#   'brilliant': 0.0029542097488921715,
#   'admirable': 0.0014771048744460858,
#   'meeting': 0.0014771048744460858,
#   'delightful': 0.0014771048744460858,
#   'charming': 0.0014771048744460858,
#   'from': 0.0029542097488921715,
#   'such': 0.0014771048744460858,
#   'all': 0.019202363367799114,
#   'impossible': 0.004431314623338257,
#   'being': 0.004431314623338257,
#   'always': 0.0029542097488921715,
#   'your': 0.005908419497784343,
#   'breaking': 0.0014771048744460858,
#   'really': 0.0029542097488921715,
#   'treating': 0.0014771048744460858,
#   'much': 0.0029542097488921715,
#   'full': 0.004431314623338257,
#   '!': 0.007385524372230428,
#   'no': 0.007385524372230428,
#   'strange': 0.0014771048744460858,
#   'beyond': 0.0014771048744460858,
#   'admiration': 0.0014771048744460858,
#   'now': 0.004431314623338257,
#   'his': 0.0103397341211226,
#   'my': 0.03840472673559823,
#   'thy': 0.007385524372230428,
#   'god': 0.0014771048744460858,
#   ',': 0.005908419497784343,
#   'it': 0.007385524372230428,
#   'one': 0.0103397341211226,
#   'that': 0.01624815361890694,
#   'done': 0.0029542097488921715,
#   'holy': 0.0014771048744460858,
#   'thine': 0.0014771048744460858,
#   'among': 0.0014771048744460858,
#   'nothing': 0.004431314623338257,
#   'he': 0.013293943870014771,
#   'david': 0.0014771048744460858,
#   'but': 0.0029542097488921715,
#   'blood': 0.0014771048744460858,
#   'ahasuerus': 0.0014771048744460858,
#   'come': 0.0029542097488921715,
#   'new': 0.0014771048744460858,
#   'also': 0.0103397341211226,
#   'vanity': 0.0014771048744460858,
#   'our': 0.0029542097488921715,
#   'as': 0.0014771048744460858,
#   'zion': 0.0014771048744460858,
#   'jerusalem': 0.0014771048744460858,
#   'pharaoh': 0.0014771048744460858,
#   'their': 0.0014771048744460858,
#   'wickedness': 0.0014771048744460858,
#   'elias': 0.0014771048744460858,
#   'john': 0.0014771048744460858,
#   'jesus': 0.0029542097488921715,
#   'indeed': 0.004431314623338257,
#   'again': 0.0014771048744460858,
#   'of': 0.004431314623338257,
#   'life': 0.0029542097488921715,
#   'for': 0.004431314623338257,
#   'good': 0.0029542097488921715,
#   'offered': 0.0014771048744460858,
#   'expedient': 0.0014771048744460858,
#   'right': 0.0014771048744460858,
#   'well': 0.0014771048744460858,
#   'thankworthy': 0.0014771048744460858,
#   'acceptable': 0.0014771048744460858,
#   'love': 0.0014771048744460858,
#   'sweet': 0.0014771048744460858,
#   'only': 0.0014771048744460858,
#   'another': 0.0014771048744460858,
#   'her': 0.0029542097488921715,
#   'may': 0.0014771048744460858,
#   'complete': 0.0014771048744460858,
#   'simply': 0.0014771048744460858,
#   'suicide': 0.0014771048744460858,
#   'vengeance': 0.0014771048744460858,
#   'ten': 0.0014771048744460858,
#   'taken': 0.0014771048744460858,
#   'something': 0.0029542097488921715,
#   'rather': 0.0014771048744460858,
#   'more': 0.005908419497784343,
#   'talk': 0.0014771048744460858,
#   'absurd': 0.0029542097488921715,
#   '.': 0.0014771048744460858,
#   'nonsense': 0.0014771048744460858,
#   'true': 0.0014771048744460858,
#   'getting': 0.0014771048744460858,
#   'so': 0.0029542097488921715,
#   'scandalous': 0.0014771048744460858,
#   'enough': 0.0014771048744460858,
#   'mr': 0.0014771048744460858,
#   'fun': 0.0014771048744460858,
#   'quizzing': 0.0014771048744460858,
#   'telling': 0.0014771048744460858,
#   'downright': 0.0014771048744460858,
#   'excellent': 0.0014771048744460858,
#   'some': 0.004431314623338257,
#   'called': 0.0014771048744460858,
#   'using': 0.0014771048744460858,
#   'charing': 0.0014771048744460858,
#   'marvellous': 0.0014771048744460858,
#   'worse': 0.0014771048744460858,
#   'both': 0.0014771048744460858,
#   'heightened': 0.0014771048744460858,
#   'obvious': 0.0014771048744460858,
#   'on': 0.0014771048744460858,
#   'perhaps': 0.0014771048744460858,
#   'dispensed': 0.0014771048744460858,
#   'servitude': 0.0014771048744460858,
#   'old': 0.0014771048744460858,
#   'trebonius': 0.0014771048744460858,
#   'wondrous': 0.0014771048744460858,
#   'miching': 0.0014771048744460858,
#   'hyre': 0.0014771048744460858,
#   'counter': 0.0014771048744460858,
#   'i': 0.0014771048744460858,
#   'meere': 0.0014771048744460858,
#   'cheapely': 0.0014771048744460858,
#   'ocean': 0.0014771048744460858,
#   'cicerone': 0.0014771048744460858,
#   'curious': 0.0014771048744460858},
#  'is_three': {'times': 0.5, 'a': 0.5},
#  'three_times': {'as': 0.05128205128205128,
#   'over': 0.1282051282051282,
#   'every': 0.02564102564102564,
#   '--': 0.02564102564102564,
#   'this': 0.02564102564102564,
#   'a': 0.07692307692307693,
#   'in': 0.10256410256410256,
#   'thou': 0.02564102564102564,
#   '?': 0.05128205128205128,
#   ':': 0.10256410256410256,
#   '.': 0.05128205128205128,
#   ',': 0.1282051282051282,
#   'did': 0.02564102564102564,
#   'to': 0.02564102564102564,
#   ';': 0.02564102564102564,
#   'at': 0.05128205128205128,
#   'had': 0.02564102564102564,
#   'repeated': 0.02564102564102564,
#   'his': 0.02564102564102564},
#  'times_as': {'large.': 0.2, 'large': 0.4, 'many': 0.2},
#  'as_large.': {'--': 1.0},
#  'large._--': {'and': 1.0},
#  'you_have': {'never': 0.029612756264236904,
#   'had': 0.018223234624145785,
#   'in': 0.00683371298405467,
#   'forgotten': 0.004555808656036446,
#   'been': 0.0683371298405467,
#   'drawn': 0.002277904328018223,
#   'given': 0.009111617312072893,
#   'made': 0.02733485193621868,
#   'ever': 0.009111617312072893,
#   'another': 0.002277904328018223,
#   'improved': 0.002277904328018223,
#   'cured': 0.002277904328018223,
#   'told': 0.004555808656036446,
#   ',': 0.02050113895216401,
#   ';': 0.009111617312072893,
#   'emma': 0.002277904328018223,
#   'seen': 0.03189066059225513,
#   'long': 0.002277904328018223,
#   'not': 0.0683371298405467,
#   'done': 0.04783599088838269,
#   'a': 0.03644646924829157,
#   'such': 0.004555808656036446,
#   'only': 0.011389521640091117,
#   'spoken': 0.002277904328018223,
#   'nothing': 0.011389521640091117,
#   'any': 0.011389521640091117,
#   'sung': 0.002277904328018223,
#   'prevailed': 0.002277904328018223,
#   'the': 0.02733485193621868,
#   'overrated': 0.002277904328018223,
#   'many': 0.002277904328018223,
#   'heard': 0.018223234624145785,
#   'scolded': 0.002277904328018223,
#   'lived': 0.004555808656036446,
#   'every': 0.002277904328018223,
#   'your': 0.00683371298405467,
#   'found': 0.004555808656036446,
#   'shewn': 0.002277904328018223,
#   'hit': 0.002277904328018223,
#   'some': 0.002277904328018223,
#   'borne': 0.002277904328018223,
#   '!': 0.002277904328018223,
#   'pleasant': 0.002277904328018223,
#   'asserted': 0.002277904328018223,
#   'always': 0.002277904328018223,
#   'difficulties': 0.002277904328018223,
#   'an': 0.004555808656036446,
#   'answered': 0.002277904328018223,
#   'no': 0.0387243735763098,
#   'described': 0.002277904328018223,
#   'from': 0.002277904328018223,
#   'already': 0.004555808656036446,
#   'received': 0.002277904328018223,
#   'said': 0.00683371298405467,
#   'often': 0.002277904328018223,
#   'anticipated': 0.002277904328018223,
#   'now': 0.004555808656036446,
#   'supposed': 0.002277904328018223,
#   'taken': 0.002277904328018223,
#   'set': 0.004555808656036446,
#   'perhaps': 0.002277904328018223,
#   'something': 0.004555808656036446,
#   'probably': 0.004555808656036446,
#   'too': 0.002277904328018223,
#   'believed': 0.002277904328018223,
#   'got': 0.025056947608200455,
#   'certainly': 0.004555808656036446,
#   'proved': 0.009111617312072893,
#   'inflicted': 0.002277904328018223,
#   'consoled': 0.002277904328018223,
#   'offended': 0.002277904328018223,
#   'conspired': 0.002277904328018223,
#   'saved': 0.00683371298405467,
#   'all': 0.004555808656036446,
#   "n't": 0.02050113895216401,
#   'of': 0.004555808656036446,
#   'baked': 0.002277904328018223,
#   'just': 0.00683371298405467,
#   'denied': 0.002277904328018223,
#   'blasphemed': 0.002277904328018223,
#   'kept': 0.00683371298405467,
#   'inside': 0.002277904328018223,
#   'wrecked': 0.002277904328018223,
#   'planned': 0.002277904328018223,
#   'tumbled': 0.002277904328018223,
#   'remained': 0.002277904328018223,
#   'betrayed': 0.002277904328018223,
#   'mistaken': 0.002277904328018223,
#   'called': 0.002277904328018223,
#   'come': 0.00683371298405467,
#   'doubtless': 0.002277904328018223,
#   'to': 0.009111617312072893,
#   'here': 0.002277904328018223,
#   'guessed': 0.002277904328018223,
#   'so': 0.002277904328018223,
#   'known': 0.002277904328018223,
#   'irritated': 0.002277904328018223,
#   'one': 0.002277904328018223,
#   'dropped': 0.002277904328018223,
#   'it': 0.00683371298405467,
#   'evidently': 0.002277904328018223,
#   'put': 0.002277904328018223,
#   'helped': 0.002277904328018223,
#   'bicycles': 0.002277904328018223,
#   'expelled': 0.002277904328018223,
#   'red': 0.002277904328018223,
#   'eightpence': 0.002277904328018223,
#   'conducted': 0.002277904328018223,
#   'lost': 0.002277904328018223,
#   'changed': 0.002277904328018223,
#   'turned': 0.002277904328018223,
#   'really': 0.002277904328018223,
#   'more': 0.004555808656036446,
#   'pronounced': 0.002277904328018223,
#   'time': 0.002277904328018223,
#   'spoiled': 0.004555808656036446,
#   'spent': 0.002277904328018223,
#   'sense': 0.002277904328018223,
#   'brought': 0.004555808656036446,
#   'me': 0.002277904328018223,
#   'left': 0.004555808656036446,
#   'used': 0.002277904328018223,
#   'gone': 0.002277904328018223,
#   'quarrelled': 0.002277904328018223,
#   '.': 0.002277904328018223,
#   '?': 0.002277904328018223,
#   'my': 0.004555808656036446,
#   'him': 0.002277904328018223,
#   'broken': 0.002277904328018223,
#   'rebelled': 0.002277904328018223,
#   'as': 0.002277904328018223,
#   'candour': 0.002277904328018223,
#   'promised': 0.002277904328018223,
#   'but': 0.002277904328018223,
#   'companions': 0.002277904328018223,
#   'little': 0.002277904328018223,
#   'even': 0.002277904328018223,
#   'thoughts': 0.002277904328018223,
#   'restored': 0.002277904328018223,
#   'for': 0.002277904328018223,
#   'anything': 0.002277904328018223,
#   'once': 0.002277904328018223,
#   'ten': 0.002277904328018223,
#   'two': 0.002277904328018223,
#   'pretty': 0.002277904328018223,
#   'imparted': 0.002277904328018223,
#   'peopled': 0.002277904328018223,
#   'waited': 0.002277904328018223,
#   'slumber': 0.002277904328018223,
#   'follow': 0.002277904328018223},
#  'have_never': {'any': 0.014705882352941176,
#   'seen': 0.10294117647058823,
#   'been': 0.27941176470588236,
#   'known': 0.058823529411764705,
#   'sought': 0.014705882352941176,
#   'thought': 0.029411764705882353,
#   'had': 0.058823529411764705,
#   'fixed': 0.014705882352941176,
#   'asked': 0.014705882352941176,
#   'gone': 0.029411764705882353,
#   'yet': 0.029411764705882353,
#   'mentioned': 0.014705882352941176,
#   'finished': 0.014705882352941176,
#   'told': 0.014705882352941176,
#   'forgiven': 0.014705882352941176,
#   'eaten': 0.014705882352941176,
#   'heard': 0.029411764705882353,
#   'even': 0.014705882352941176,
#   'in': 0.014705882352941176,
#   'come': 0.014705882352941176,
#   'descended': 0.014705882352941176,
#   'regretted': 0.014705882352941176,
#   'spoken': 0.014705882352941176,
#   'considered': 0.014705882352941176,
#   'touched': 0.014705882352941176,
#   'hostilely': 0.014705882352941176,
#   'chanced': 0.014705882352941176,
#   'marked': 0.014705882352941176,
#   'parted': 0.014705882352941176,
#   'heeded': 0.014705882352941176},
#  'never_any': {'odd': 0.25, 'burst': 0.25, 'thing': 0.25, 'more': 0.25},
#  'any_odd': {'humours': 1.0},
#  'my_dear': {'.': 0.06134969325153374,
#   ',': 0.3098159509202454,
#   'papa': 0.012269938650306749,
#   'harriet': 0.018404907975460124,
#   'sir': 0.06134969325153374,
#   '--': 0.009202453987730062,
#   'madam': 0.03374233128834356,
#   'emma': 0.06441717791411043,
#   'isabella': 0.009202453987730062,
#   ';': 0.018404907975460124,
#   'mrs.': 0.006134969325153374,
#   '?': 0.02147239263803681,
#   'miss': 0.046012269938650305,
#   'jane': 0.03067484662576687,
#   'aunt': 0.003067484662576687,
#   'child': 0.009202453987730062,
#   'friend': 0.009202453987730062,
#   'mr.': 0.02147239263803681,
#   'father': 0.003067484662576687,
#   'mary': 0.003067484662576687,
#   'frederick': 0.003067484662576687,
#   'admiral': 0.006134969325153374,
#   'cousin': 0.006134969325153374,
#   'anne': 0.006134969325153374,
#   'mrs': 0.012269938650306749,
#   'husband': 0.003067484662576687,
#   'penelope': 0.003067484662576687,
#   'fanny': 0.006134969325153374,
#   'marianne': 0.006134969325153374,
#   'elinor': 0.009202453987730062,
#   'willoughby': 0.003067484662576687,
#   'mother': 0.012269938650306749,
#   'prudent': 0.003067484662576687,
#   'sister': 0.009202453987730062,
#   '!': 0.02147239263803681,
#   'edward': 0.006134969325153374,
#   "ma'am": 0.003067484662576687,
#   'son': 0.006134969325153374,
#   'dinah': 0.003067484662576687,
#   'paws': 0.003067484662576687,
#   'fellow': 0.024539877300613498,
#   'lady': 0.003067484662576687,
#   'tuesday': 0.003067484662576687,
#   'little': 0.006134969325153374,
#   'brother': 0.003067484662576687,
#   'rosamond': 0.006134969325153374,
#   'love': 0.003067484662576687,
#   'bursal': 0.006134969325153374,
#   'young': 0.003067484662576687,
#   'uncle': 0.003067484662576687,
#   'hal': 0.003067484662576687,
#   'nephew': 0.003067484662576687,
#   "''": 0.003067484662576687,
#   'louisa': 0.003067484662576687,
#   'boy': 0.003067484662576687,
#   'good': 0.003067484662576687,
#   'ishmael': 0.003067484662576687,
#   'comrade': 0.006134969325153374,
#   'friends': 0.003067484662576687,
#   'brothers': 0.003067484662576687,
#   'children': 0.003067484662576687},
#  'dear_.': {"''": 0.12,
#   'he': 0.04,
#   'i': 0.12,
#   'that': 0.08,
#   'with': 0.04,
#   'she': 0.08,
#   'did': 0.04,
#   'but': 0.04,
#   "'lord": 0.04,
#   '(': 0.04},
#  '``_how': {'often': 0.025974025974025976,
#   'much': 0.045454545454545456,
#   'do': 0.12987012987012986,
#   'you': 0.01948051948051948,
#   'very': 0.025974025974025976,
#   'd': 0.025974025974025976,
#   'sorry': 0.006493506493506494,
#   'odd': 0.012987012987012988,
#   'lucky': 0.012987012987012988,
#   '?': 0.01948051948051948,
#   'is': 0.045454545454545456,
#   'i': 0.012987012987012988,
#   'could': 0.025974025974025976,
#   'sure': 0.006493506493506494,
#   'delighted': 0.012987012987012988,
#   'vexed': 0.006493506493506494,
#   'mr': 0.006493506493506494,
#   'strange': 0.032467532467532464,
#   'can': 0.07792207792207792,
#   'happy': 0.01948051948051948,
#   'horrid': 0.006493506493506494,
#   'charming': 0.006493506493506494,
#   'playful': 0.006493506493506494,
#   'unlucky': 0.006493506493506494,
#   'surprised': 0.006493506493506494,
#   'it': 0.012987012987012988,
#   'good': 0.01948051948051948,
#   'long': 0.03896103896103896,
#   '!': 0.006493506493506494,
#   'then': 0.006493506493506494,
#   'pretty': 0.012987012987012988,
#   'shall': 0.012987012987012988,
#   'did': 0.032467532467532464,
#   'funny': 0.012987012987012988,
#   'high': 0.006493506493506494,
#   'doth': 0.012987012987012988,
#   'dare': 0.012987012987012988,
#   'glorious': 0.006493506493506494,
#   'inconsistent': 0.006493506493506494,
#   'to': 0.006493506493506494,
#   'true': 0.006493506493506494,
#   'was': 0.01948051948051948,
#   'came': 0.012987012987012988,
#   'should': 0.006493506493506494,
#   'grateful': 0.006493506493506494,
#   'does': 0.006493506493506494,
#   'goes': 0.006493506493506494,
#   'nice': 0.006493506493506494,
#   "'s": 0.006493506493506494,
#   'hard': 0.006493506493506494,
#   'many': 0.006493506493506494,
#   'foolish': 0.006493506493506494,
#   'provoking': 0.006493506493506494,
#   'old': 0.012987012987012988,
#   ',': 0.006493506493506494,
#   'quietly': 0.006493506493506494,
#   'good-natured': 0.006493506493506494,
#   'cruel': 0.006493506493506494,
#   'far': 0.006493506493506494,
#   'now': 0.012987012987012988,
#   'wondrous': 0.006493506493506494,
#   'heading': 0.006493506493506494},
#  ...}

# %%
#testing if it works
s = input('Enter text:')
s = s.split()

q = s[-2]+'_'+s[-1]

try:
    l = trigram_dic[q]
    l = sorted(l.items(), key=lambda item: item[1],reverse=True)
    print(l[0:5])
    
except Exception:
    print([])
# Out:
# Enter text:this is
# [('the', 0.3515509601181684), ('a', 0.09748892171344166), ('not', 0.0413589364844904), ('my', 0.03840472673559823), ('all', 0.019202363367799114)]

# %%
# saving the trigram dictionary 
import pickle
with open('trigram_dictionary.pkl', 'wb') as f:
    pickle.dump(trigram_dic, f)
